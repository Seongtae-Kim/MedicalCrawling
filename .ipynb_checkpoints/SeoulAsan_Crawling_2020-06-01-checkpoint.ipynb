# %%
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from collections import defaultdict

# %%
browser = webdriver.Firefox()

# %% [markdown]
# # 신체 정보 추출

# %%
class Body:
    availableTabs=defaultdict() # 현재페이지에 이용가능한 탭과 그 링크
    descrips=defaultdict()
    name="" #신체이름
    part="" #해당부위
    disease=""#해당 질환
    medDep="" #해당 진료과
    related_diseases=[] # 관련질환
    related_interventions=[] # 관련시술/수술/검사

# %%
# 인체 정보 총 272개
bodyList = []
st = "http://www.amc.seoul.kr/asan/healthinfo/body/bodyDetail.do?bodyId="

for i in range(272):
        stnew = st + str(i+1)
        bodyList.append(stnew)

# %%
#http://www.amc.seoul.kr/asan/healthinfo/body/bodyDetail.do?
#bodyId=150&   신체 id
#tabIndex=1&   탭 번호(0: 설명, 1: 관련질환, 3: 관련시술/수술/검사 인듯)
#pageIndex=1   페이지 번호(결과가 여러개일 경우 페이지 번호도 여럿)

def body_extract(bodyList):
    bodies = []
    for address in bodyList: # http://www.amc.seoul.kr/asan/healthinfo/body/bodyDetail.do?bodyId=1
        
        browser.get(address)
        
        if browser.find_elements_by_class_name("contTitle")[0].text == "()":
            continue
        
        body = Body()
        
        tableIndex= ["1", "3"]

        # 신체 이름
        name = ""
        summaryBox = browser.find_elements_by_class_name("contBox")
        title = summaryBox[0].find_elements_by_class_name("contTitle")
        body.name = title[0].text
        # 신체 이름 - 끝

        # 부위명/질환명/진료과
        summaries = summaryBox[0].find_elements_by_tag_name("dd")
        if len(summaries) >= 1:
            body.part = summaries[0].text
            if len(summaries) >= 2:
                body.disease = summaries[1].text
                if len(summaries) == 3:
                    body.medDep = summaries[2].text
        # 부위명/질환명/진료과 - 끝

        # 본문 정리 -> 본문 정리는 기본 url로 진행 가능
        ds = {}
        descOuter = browser.find_elements_by_class_name("contDescription")
        definitions = descOuter[0].find_elements_by_tag_name("dt")
        descriptions = descOuter[0].find_elements_by_tag_name("dd")
        if len(definitions) == len(descriptions):
            for defi, des in zip(definitions, descriptions):
                ds[defi.text] = des.text
            body.descrips = ds
        else:
            print("정의와 설명의 개수가 다름")
        # 본문 정리 - 끝

        # 다음 탭으로 이동
        nextUrl = address + "&tabIndex=" + tableIndex[0]
        browser.get(nextUrl)

        # 페이지 길이 파악
        pageOuter = browser.find_elements_by_class_name("numPagingSec")
        if len(pageOuter) >= 1:
            pages = pageOuter[0].find_elements_by_tag_name("a")
            pageLen = int(pages[-1].text) # 전체 페이지 길이
        # 페이지 길이 파악 - 끝

        urlToExplore = [] # 페이지 수에 따라 조사해야 할 url 리스트
        for i in range(pageLen):
                nextUrl = address + "&tabIndex=" + tableIndex[0] + "&pageIndex=" + str(i+1)
                urlToExplore.append(nextUrl)
                
                
        #관련 질병 추출
        dis = []
        for url in urlToExplore:
            browser.get(url)
            diseasesOuter = browser.find_elements_by_class_name("listCont")
            if len(diseasesOuter) >= 1:
                diseases = diseasesOuter[0].find_elements_by_class_name("contTitle")
                for disease in diseases:
                    dis.append(disease.text)
        body.related_diseases = dis
        # 관련 질병 추출 -끝
        
        # 다음 탭으로 이동
        nextUrl = address + "&tabIndex=" + tableIndex[1]
        browser.get(nextUrl)

        # 페이지 길이 파악
        pageOuter = browser.find_elements_by_class_name("numPagingSec")
        if len(pageOuter) >= 1:
            pages = pageOuter[0].find_elements_by_tag_name("a")
            pageLen = int(pages[-1].text) # 전체 페이지 길이
        # 페이지 길이 파악 - 끝

        urlToExplore = [] # 페이지 수에 따라 조사해야 할 url 리스트
        for i in range(pageLen):
                nextUrl = address + "&tabIndex=" + tableIndex[1] + "&pageIndex=" + str(i+1)
                urlToExplore.append(nextUrl)
                
        #관련 검사/시술/수술
        inter = []
        for url in urlToExplore:
            browser.get(url)
            interventionsOuter = browser.find_elements_by_class_name("listCont")
            if len(interventionsOuter) >= 1:
                interventions = interventionsOuter[0].find_elements_by_class_name("contTitle")
                for intervention in interventions:
                    inter.append(intervention.text)
        body.related_interventions = inter
        #관련 검사/시술/수술 - 끝
        
        bodies.append(body)
        print(body.name, "완료. 현재 완료한 객체: ", len(bodies))
    return bodies

# %%
bodies = body_extract(bodyList)
# Out:
# 간(Liver) 완료. 현재 완료한 객체:  1
# 갈비뼈(Rib) 완료. 현재 완료한 객체:  2
# 갑상선(Thyroid) 완료. 현재 완료한 객체:  3
# 겨드랑이(Axilla) 완료. 현재 완료한 객체:  4
# 견갑골(Scapula) 완료. 현재 완료한 객체:  5
# 고환(Testis) 완료. 현재 완료한 객체:  6
# 골반(Pelvis) 완료. 현재 완료한 객체:  7
# 골수(Bone marrow) 완료. 현재 완료한 객체:  8
# 관절(Joint) 완료. 현재 완료한 객체:  9
# 괄약근(Sphincter) 완료. 현재 완료한 객체:  10
# 귀(Ear) 완료. 현재 완료한 객체:  11
# 근육(Muscle) 완료. 현재 완료한 객체:  12
# 기관지(Bronchus) 완료. 현재 완료한 객체:  13
# 난소(Ovary) 완료. 현재 완료한 객체:  14
# 뇌(Brain) 완료. 현재 완료한 객체:  15
# 뇌하수체(Pituitary gland) 완료. 현재 완료한 객체:  16
# 눈(Eye) 완료. 현재 완료한 객체:  17
# 뉴런(Neuron) 완료. 현재 완료한 객체:  18
# 담낭(Gallbladder) 완료. 현재 완료한 객체:  19
# 대뇌(Cerebrum) 완료. 현재 완료한 객체:  20
# 대장(Large intestine) 완료. 현재 완료한 객체:  21
# 땀샘(Sweat gland) 완료. 현재 완료한 객체:  22
# 림프(Lymph) 완료. 현재 완료한 객체:  23
# 말초신경계(Peripheral Nerve System) 완료. 현재 완료한 객체:  24
# 맹장(Cecum) 완료. 현재 완료한 객체:  25
# 충수(Appendix) 완료. 현재 완료한 객체:  26
# 무릎(Knee) 완료. 현재 완료한 객체:  27
# 발(Foot) 완료. 현재 완료한 객체:  28
# 방광(Bladder) 완료. 현재 완료한 객체:  29
# 복강(Abdominal cavity) 완료. 현재 완료한 객체:  30
# 부신(Adrenal gland) 완료. 현재 완료한 객체:  31
# 비장(Spleen) 완료. 현재 완료한 객체:  32
# 뼈(Bone) 완료. 현재 완료한 객체:  33
# 성장판(Physeal plate) 완료. 현재 완료한 객체:  34
# 성 호르몬(Sex hormone) 완료. 현재 완료한 객체:  35
# 소장(Small intestine) 완료. 현재 완료한 객체:  36
# 손(Hand) 완료. 현재 완료한 객체:  37
# 식도(Esophagus) 완료. 현재 완료한 객체:  38
# 신장(Kidney) 완료. 현재 완료한 객체:  39
# 심장(Heart) 완료. 현재 완료한 객체:  40
# 심장판막(Cardiac valves) 완료. 현재 완료한 객체:  41
# 어깨(Shoulder) 완료. 현재 완료한 객체:  42
# 외음부(Vulva) 완료. 현재 완료한 객체:  43
# 위(Stomach) 완료. 현재 완료한 객체:  44
# 유방(Breast) 완료. 현재 완료한 객체:  45
# 음경(Penis) 완료. 현재 완료한 객체:  46
# 인대(Ligament) 완료. 현재 완료한 객체:  47
# 인두(Pharynx) 완료. 현재 완료한 객체:  48
# 입(Mouth) 완료. 현재 완료한 객체:  49
# 자궁(Uterus) 완료. 현재 완료한 객체:  50
# 자율신경계(Autonomic Nervous System) 완료. 현재 완료한 객체:  51
# 전립선(Prostate) 완료. 현재 완료한 객체:  52
# 조혈모세포(Hematopoietic stem cell) 완료. 현재 완료한 객체:  53
# 중추신경계(Central nervous system) 완료. 현재 완료한 객체:  54
# 질(Vagina) 완료. 현재 완료한 객체:  55
# 척추(Vertebra) 완료. 현재 완료한 객체:  56
# 추간판(Intervertebral disc) 완료. 현재 완료한 객체:  57
# 췌장(Pancreas) 완료. 현재 완료한 객체:  58
# 치아(Teeth) 완료. 현재 완료한 객체:  59
# 코(External nose) 완료. 현재 완료한 객체:  60
# 태반(Placenta) 완료. 현재 완료한 객체:  61
# 팔(Upper limb) 완료. 현재 완료한 객체:  62
# 편도(Tonsil) 완료. 현재 완료한 객체:  63
# 폐(Lung) 완료. 현재 완료한 객체:  64
# 피부(Skin) 완료. 현재 완료한 객체:  65
# 항문(Anus) 완료. 현재 완료한 객체:  66
# 혈관(Blood vessel) 완료. 현재 완료한 객체:  67
# 혈구(Hemocyte) 완료. 현재 완료한 객체:  68
# 횡격막(Diaphragm) 완료. 현재 완료한 객체:  69
# 후두(Larynx) 완료. 현재 완료한 객체:  70
# 엉덩이(Hip) 완료. 현재 완료한 객체:  71
# 옆구리(Flank) 완료. 현재 완료한 객체:  72
# 주관절(Elbow joint) 완료. 현재 완료한 객체:  73
# 모세혈관(Capillary vessel) 완료. 현재 완료한 객체:  74
# 혈액 순환(Blood circulation) 완료. 현재 완료한 객체:  75
# 시냅스(Synapse) 완료. 현재 완료한 객체:  76
# 생식기(Genitalia) 완료. 현재 완료한 객체:  77
# 관상동맥(Coronary artery) 완료. 현재 완료한 객체:  78
# 교감신경(Sympathetic nerve) 완료. 현재 완료한 객체:  79
# 부교감신경(Parasympathetic nerve) 완료. 현재 완료한 객체:  80
# 뇌신경(Cranial nerve) 완료. 현재 완료한 객체:  81
# 슬관절(Knee joint) 완료. 현재 완료한 객체:  82
# 침샘(Salivary gland) 완료. 현재 완료한 객체:  83
# 젖샘(Mammary glands) 완료. 현재 완료한 객체:  84
# 배(Abdomen) 완료. 현재 완료한 객체:  85
# 연골(Cartilage) 완료. 현재 완료한 객체:  86
# 점막(Mucous membrane) 완료. 현재 완료한 객체:  87
# 고관절(Hip joint) 완료. 현재 완료한 객체:  88
# 손가락(Finger) 완료. 현재 완료한 객체:  89
# 발가락(Toe) 완료. 현재 완료한 객체:  90
# 경추(Cervical vertebrae) 완료. 현재 완료한 객체:  91
# 요추(Lumbar vertebrae) 완료. 현재 완료한 객체:  92
# 꼬리뼈(Coccyx) 완료. 현재 완료한 객체:  93
# 척수(Spinal cord) 완료. 현재 완료한 객체:  94
# 동맥(Artery) 완료. 현재 완료한 객체:  95
# 정맥(Vein) 완료. 현재 완료한 객체:  96
# 적혈구(RBC, Red Blood Cell) 완료. 현재 완료한 객체:  97
# 혈소판(Platelet) 완료. 현재 완료한 객체:  98
# 백혈구(WBC, White Blood Cell) 완료. 현재 완료한 객체:  99
# 림프절(Lymph node) 완료. 현재 완료한 객체:  100
# 대뇌피질(Cerebral cortex) 완료. 현재 완료한 객체:  101
# 얼굴신경(Facial nerve) 완료. 현재 완료한 객체:  102
# 혈관미주신경(Vasovagal) 완료. 현재 완료한 객체:  103
# 호르몬(Hormone) 완료. 현재 완료한 객체:  104
# 남성호르몬(Male hormone) 완료. 현재 완료한 객체:  105
# 여성호르몬(Female hormone) 완료. 현재 완료한 객체:  106
# 성장호르몬(Growth hormone) 완료. 현재 완료한 객체:  107
# 자궁경부(Uterine cervix) 완료. 현재 완료한 객체:  108
# 탯줄(Umbilical cord) 완료. 현재 완료한 객체:  109
# 십이지장(Duodenum) 완료. 현재 완료한 객체:  110
# 결막(Conjunctiva) 완료. 현재 완료한 객체:  111
# 망막(Retina) 완료. 현재 완료한 객체:  112
# 눈물관(Lacrimal duct) 완료. 현재 완료한 객체:  113
# 고막(Tympanic membrane) 완료. 현재 완료한 객체:  114
# 기도(Airway) 완료. 현재 완료한 객체:  115
# 폐포(Alveolus) 완료. 현재 완료한 객체:  116
# 부갑상샘(Parathyroid gland) 완료. 현재 완료한 객체:  117
# 성대(Vocal cord) 완료. 현재 완료한 객체:  118
# 두피(Scalp) 완료. 현재 완료한 객체:  119
# 피하지방(Subcutaneous fat) 완료. 현재 완료한 객체:  120
# 요도(Urethra) 완료. 현재 완료한 객체:  121
# 간정맥(Hepatic vein) 완료. 현재 완료한 객체:  122
# 간문맥(Portal vein) 완료. 현재 완료한 객체:  123
# 담관(Bile duct) 완료. 현재 완료한 객체:  124
# 이자섬(Pancreatic islets) 완료. 현재 완료한 객체:  125
# 부신피질(Adrenal cortex) 완료. 현재 완료한 객체:  126
# 게실(Diverticulum) 완료. 현재 완료한 객체:  127
# 공장(Jejunum) 완료. 현재 완료한 객체:  128
# 회장(Ileum) 완료. 현재 완료한 객체:  129
# 융모(Villus) 완료. 현재 완료한 객체:  130
# 비장 동맥(Splenic artery) 완료. 현재 완료한 객체:  131
# 흉추(Thoracic vertebra) 완료. 현재 완료한 객체:  132
# 사구체(Glomerulus) 완료. 현재 완료한 객체:  133
# 신장단위(Nephron) 완료. 현재 완료한 객체:  134
# 신우(Renal pelvis) 완료. 현재 완료한 객체:  135
# 신배(Renal calyx) 완료. 현재 완료한 객체:  136
# 요관(Ureter) 완료. 현재 완료한 객체:  137
# 신장피질(Renal cortex) 완료. 현재 완료한 객체:  138
# 뇌간(Brainstem) 완료. 현재 완료한 객체:  139
# 중뇌(Midbrain) 완료. 현재 완료한 객체:  140
# 교뇌(Pons) 완료. 현재 완료한 객체:  141
# 연수(Medulla) 완료. 현재 완료한 객체:  142
# 뇌실(Ventricle) 완료. 현재 완료한 객체:  143
# 소뇌(Cerebellum) 완료. 현재 완료한 객체:  144
# 시상하부(Hypothalamus) 완료. 현재 완료한 객체:  145
# 시상(Thalamus) 완료. 현재 완료한 객체:  146
# 해마(Hippocampus) 완료. 현재 완료한 객체:  147
# 전두엽(Frontal lobe) 완료. 현재 완료한 객체:  148
# 수막(Meninx) 완료. 현재 완료한 객체:  149
# 거미막(Arachnoid membrane) 완료. 현재 완료한 객체:  150
# 혈액뇌장벽(Blood-brain barrier) 완료. 현재 완료한 객체:  151
# 두개골(Cranium) 완료. 현재 완료한 객체:  152
# 천문(Fontanelle) 완료. 현재 완료한 객체:  153
# 뇌하수체호르몬(Pituitary hormone) 완료. 현재 완료한 객체:  154
# 부신피질호르몬(Adrenal cortex hormone) 완료. 현재 완료한 객체:  155
# 볼기근(Gluteus muscle) 완료. 현재 완료한 객체:  156
# 배근육(Abdominal muscle) 완료. 현재 완료한 객체:  157
# 힘줄(Tendon) 완료. 현재 완료한 객체:  158
# 섬유연골(Fibrocartilage) 완료. 현재 완료한 객체:  159
# 뼈막(Periosteum) 완료. 현재 완료한 객체:  160
# 근막(Fascia) 완료. 현재 완료한 객체:  161
# 척주관(Vertebral canal) 완료. 현재 완료한 객체:  162
# 황색인대(Ligamentum flavum) 완료. 현재 완료한 객체:  163
# 빗장뼈(Clavicle) 완료. 현재 완료한 객체:  164
# 요골(Radius) 완료. 현재 완료한 객체:  165
# 치골(Pubis) 완료. 현재 완료한 객체:  166
# 좌골(Ischium) 완료. 현재 완료한 객체:  167
# 천골(Sacrum) 완료. 현재 완료한 객체:  168
# 대퇴골(Femur) 완료. 현재 완료한 객체:  169
# 경골(Tibia) 완료. 현재 완료한 객체:  170
# 비골(Fibula) 완료. 현재 완료한 객체:  171
# 외분비샘(Exocrine gland) 완료. 현재 완료한 객체:  172
# 무릎 연골(Knee cartilage) 완료. 현재 완료한 객체:  173
# 무릎 인대(Knee ligament) 완료. 현재 완료한 객체:  174
# 발목관절(Ankle joint) 완료. 현재 완료한 객체:  175
# 아킬레스건(Achilles tendon) 완료. 현재 완료한 객체:  176
# 골모세포(Osteoblast) 완료. 현재 완료한 객체:  177
# 상피세포(Epithelial cell) 완료. 현재 완료한 객체:  178
# 생식세포(Gamete) 완료. 현재 완료한 객체:  179
# 연골세포(Chondrocyte) 완료. 현재 완료한 객체:  180
# 조직구(Histiocyte) 완료. 현재 완료한 객체:  181
# 손목(Carpus) 완료. 현재 완료한 객체:  182
# 수근관(Carpal tunnel) 완료. 현재 완료한 객체:  183
# 손톱(Nail) 완료. 현재 완료한 객체:  184
# 어깨근육(Shoulder muscle) 완료. 현재 완료한 객체:  185
# 회전근개(Rotator cuff) 완료. 현재 완료한 객체:  186
# 비강(Nasal cavity) 완료. 현재 완료한 객체:  187
# 부비동(Paranasal sinus) 완료. 현재 완료한 객체:  188
# 코중격(Nasal septum) 완료. 현재 완료한 객체:  189
# 후각신경(Olfactory nerve) 완료. 현재 완료한 객체:  190
# 시각신경(Optic nerve) 완료. 현재 완료한 객체:  191
# 눈돌림신경(Oculomotor nerve) 완료. 현재 완료한 객체:  192
# 도르래신경(Trochlear nerve) 완료. 현재 완료한 객체:  193
# 삼차신경(Trigeminal nerve) 완료. 현재 완료한 객체:  194
# 전정신경(Vestibular nerve) 완료. 현재 완료한 객체:  195
# 미주신경(Vagus nerve) 완료. 현재 완료한 객체:  196
# 척수신경(Spinal nerve) 완료. 현재 완료한 객체:  197
# 엉치신경(Sacral nerve) 완료. 현재 완료한 객체:  198
# 좌골신경(Sciatic nerve) 완료. 현재 완료한 객체:  199
# 대동맥(Aorta) 완료. 현재 완료한 객체:  200
# 심방(Atrium) 완료. 현재 완료한 객체:  201
# 우심실(Right ventricle) 완료. 현재 완료한 객체:  202
# 좌심실(Left ventricle) 완료. 현재 완료한 객체:  203
# 사이막(Septum) 완료. 현재 완료한 객체:  204
# 삼첨판(Tricuspid) 완료. 현재 완료한 객체:  205
# 승모판(Mitral valve) 완료. 현재 완료한 객체:  206
# 복막(Peritoneum) 완료. 현재 완료한 객체:  207
# 배꼽(Umbilicus) 완료. 현재 완료한 객체:  208
# 후두덮개(Epiglottis) 완료. 현재 완료한 객체:  209
# 상기도(Upper airway ) 완료. 현재 완료한 객체:  210
# 뇌혈관(Cerebral vessels) 완료. 현재 완료한 객체:  211
# 온목동맥(Common carotid artery ) 완료. 현재 완료한 객체:  212
# 복부대동맥(Abdominal aorta) 완료. 현재 완료한 객체:  213
# 폐동맥(Pulmonary trunk ) 완료. 현재 완료한 객체:  214
# 신장동맥(Renal artery) 완료. 현재 완료한 객체:  215
# 비골동맥(Peroneal artery) 완료. 현재 완료한 객체:  216
# 경정맥(Jugular vein ) 완료. 현재 완료한 객체:  217
# 하대정맥(Inferior vena cava ) 완료. 현재 완료한 객체:  218
# 흉골(Sternum) 완료. 현재 완료한 객체:  219
# 흉막(Pleura) 완료. 현재 완료한 객체:  220
# 흉막강(Pleural cavity ) 완료. 현재 완료한 객체:  221
# 흉강(Thoracic cavity ) 완료. 현재 완료한 객체:  222
# 흉곽(Thoracic cage ) 완료. 현재 완료한 객체:  223
# 대흉근(Pectoralis major muscle) 완료. 현재 완료한 객체:  224
# 반고리관(Semicircular duct ) 완료. 현재 완료한 객체:  225
# 유스타키오관(Eustachian tube) 완료. 현재 완료한 객체:  226
# 달팽이관(Cochlear canal) 완료. 현재 완료한 객체:  227
# 전정기관(Vestibule) 완료. 현재 완료한 객체:  228
# 안구(Eyeball) 완료. 현재 완료한 객체:  229
# 안와(Orbit ) 완료. 현재 완료한 객체:  230
# 각막(Cornea ) 완료. 현재 완료한 객체:  231
# 공막(Sclera) 완료. 현재 완료한 객체:  232
# 포도막(Uvea ) 완료. 현재 완료한 객체:  233
# 홍채(Iris) 완료. 현재 완료한 객체:  234
# 모양체(Ciliary body) 완료. 현재 완료한 객체:  235
# 맥락막(Choroid ) 완료. 현재 완료한 객체:  236
# 수정체(Lens) 완료. 현재 완료한 객체:  237
# 유리체(Vitreous body) 완료. 현재 완료한 객체:  238
# 황반(Macula lutea) 완료. 현재 완료한 객체:  239
# 기관(Trachea) 완료. 현재 완료한 객체:  240
# 세기관지(Bronchiole ) 완료. 현재 완료한 객체:  241
# 진피(Dermis ) 완료. 현재 완료한 객체:  242
# 귀두(Glans ) 완료. 현재 완료한 객체:  243
# 부고환(Epididymis ) 완료. 현재 완료한 객체:  244
# 음낭(Scrotum ) 완료. 현재 완료한 객체:  245
# 정낭(Seminal vesicle ) 완료. 현재 완료한 객체:  246
# 대음순(Labium major) 완료. 현재 완료한 객체:  247
# 소음순(Labium minor) 완료. 현재 완료한 객체:  248
# 음핵(Clitoris ) 완료. 현재 완료한 객체:  249
# 처녀막(Hymen) 완료. 현재 완료한 객체:  250
# 유두(Nipple ) 완료. 현재 완료한 객체:  251
# 유륜(Areola ) 완료. 현재 완료한 객체:  252
# 난관(Uterine tube ) 완료. 현재 완료한 객체:  253
# 자궁내막(Endometrium) 완료. 현재 완료한 객체:  254
# 양막(Amnion ) 완료. 현재 완료한 객체:  255
# 융모막융모(Chorionic villus) 완료. 현재 완료한 객체:  256
# 황체(Corpus luteum) 완료. 현재 완료한 객체:  257
# 광대뼈(Zygomatic bone ) 완료. 현재 완료한 객체:  258
# 턱(Jaw ) 완료. 현재 완료한 객체:  259
# 턱관절(Temporomandibular joint) 완료. 현재 완료한 객체:  260
# 상악골(Maxilla ) 완료. 현재 완료한 객체:  261
# 하악골(Mandible) 완료. 현재 완료한 객체:  262
# 이하선(Parotid gland ) 완료. 현재 완료한 객체:  263
# 악하선(Submandibular gland ) 완료. 현재 완료한 객체:  264
# 설하선(Sublingual gland ) 완료. 현재 완료한 객체:  265
# 목젖(Uvula ) 완료. 현재 완료한 객체:  266
# 혀(Lingua) 완료. 현재 완료한 객체:  267
# 잇몸(Gingiva) 완료. 현재 완료한 객체:  268
# 치조(Alveolus ) 완료. 현재 완료한 객체:  269
# 입술(Lip ) 완료. 현재 완료한 객체:  270
# 흉선(Thymus) 완료. 현재 완료한 객체:  271

# %%
# http://www.amc.seoul.kr/asan/healthinfo/body/bodyDetail.do?bodyId=
# 확인용 테스트
i = 100 # 신체정보 번호 0 ~ 271 -> 272개
print("신체명: ", bodies[i].name)
print("부위명: ",bodies[i].part)
print("관련질환: ", bodies[i].disease)
print("관련 진료과: ", bodies[i].medDep)
print()
print("관련 설명: ")
for k, v in bodies[i].descrips.items():
    print(k)
    print(v)
print()
print("관련 질환명: ")
for d in bodies[i].related_diseases:
    print(d)
print()
print("관련 시술/수술/검사 명: ")
for i in bodies[i].related_interventions:
    print(i)
# Out:
# 신체명:  대뇌피질(Cerebral cortex)
# 부위명:  머리
# 관련질환:  뇌신경정신질환
# 관련 진료과:
#
# 관련 설명:
# 정의
# 대뇌피질은 대뇌반구의 바깥층을 감싸고 있는 2~3mm의 회백질 부분입니다. 회백질에는 신경세포가 모여있습니다.
# 위치
# 대뇌의 바깥층을 차지하는 부분입니다.
# 구조
# 대뇌피질은 대뇌의 표면을 감싸고 있는 신경세포들의 집합으로 대뇌의 안쪽부분에 비해 어두운 색을 띠고 있어 회백질이라 불리며 신경세포체와 모세혈관으로 이루어져 있습니다. 대뇌는 한정된 공간인 두개골 안에 있기 때문에 표면쪽으로 융기된 부분(이랑)과 사이의 움푹 들어간 부분(고랑)이 교차되어 복잡하게 주름진 표면을 형성하고 있습니다.
# 기능
# 대뇌피질은 부위에 따라서 감각, 운동, 언어기능과 같은 여러가지 기능을 수행합니다.
#
# 운동영역: 전두엽의 중심전회에 위치하며, 수의운동을 담당하는 중추입니다. 장애를 입으면 운동마비가 발생합니다.
#   전운동영역: 운동영역의 앞부분에 위치하며, 운동의 프로그램에 관여합니다. 장애를 입으면 습득한 운동을 실행하지 못하게 되는 실행증이 발생합니다.
#
# 감각영역: 두정엽의 중심후회에 위치하며, 온각과 통각 및 촉각의 중추입니다. 장애를 입으면 감각장애가 발생합니다.
#   체성감각 연합영역: 감각 영역의 뒷부분에 위치하며, 유입된 감각정보를 통합하여 이해하는 역할을 합니다. 장애를 입으면 만지고 있는 것이 무엇인지 알지 못하는 실인증이 발생합니다.
#
# 운동성 언어중추: 왼쪽대뇌반구 전두엽의 아래부분에 위치하며, 브로카영역이라 불립니다. 장애를 입으면 다른 사람이 말하는 것을 알아들을 수는 있으나 말하고 싶은 것을 조리있게 말할 수 없는 운동성 실어증이 발생합니다.
#
# 감각성 언어중추: 왼쪽대뇌반구 측두엽에 위치하며, 베르니케영역이라 불립니다. 장애를 입으면 다른 사람의 말을 이해할 수 없는 감각성 실어증이 발생합니다.
#
# 시각영역: 후두엽 안쪽 부분에 위치하며, 시각정보가 모아지는 부분입니다. 장애를 입으면 반대편의 시야를 볼 수 없게 됩니다.
#
# 청각영역: 측두엽의 횡측두회에 위치하며, 청각정보가 모아지는 부분입니다. 양쪽 귀에서 정보가 전달되기 때문에 한쪽에만 장애가 있다면 완전한 청력장애가 일어나지 않습니다.
#
# 연합영역: 운동중추와 감각중추를 제외한 모든 영역을 연합영역이라 부릅니다. 이는 각각의 운동영역이나 감각영역과 연락하여 각종 정보를 결합하는 고도의 정신활동을 수행하는데, 이 영역을 통해 기억, 상상, 학습, 의도적이고 이성적인 행동이 가능해집니다.
# 헬스팁
# 대뇌피질을 침범하는 퇴행성 질환에는 알츠하이머병과 픽병이 있으며, 주된 증상은 치매 증상입니다. 알츠하이머병은 전두엽과 측두엽, 두정-후두엽의 위축이 발생하며, 뇌실이 확장되어 정상 뇌의 크기보다 작고 무게 또한 감소합니다. 픽병은 전두엽, 측두엽이 심하게 위축되고, 대뇌피질 외측에 신경세포의 소실이 발생하는 질환입니다.
#   언어기능을 담당하는 뇌의 부위에 병이 발생하여 언어 기능에 이상이 발생하는 것을 실어증이라 합니다. 그러나 발성기관이나 청각기관의 이상으로 인한 언어장애는 실어증이라는 용어를 사용하지 않습니다.
#
# 관련 질환명:
# 뇌경색(Cerebral infarction)
# 뇌농양(Brain abscess)
# 뇌동맥 폐쇄(Occlusion of cerebral artery)
# 뇌동맥류(Cerebral aneurysm)
# 뇌염(Encephalitis)
# 뇌전증(Epilepsy)
# 뇌종양(Brain tumor)
# 뇌출혈(Cerebral hemorrhage)
# 수두증(Hydrocephalus)
# 알츠하이머병(Alzheimer's disease)
# 양성 뇌종양(Benign brain tumor)
#
# 관련 시술/수술/검사 명:

# %%
txt= ""
for body in bodies:
    txt = txt + "================================= \n"
    txt = txt + "신체명: " + body.name + "\n"
    if len(body.part) >= 1:
        txt = txt + "부위명: " + body.part + "\n"
    if len(body.disease) >= 1:
        txt = txt + "관련질환: " + body.disease + "\n"
    if len(body.medDep) >= 1:
        txt = txt + "관련 진료과: " + body.medDep + "\n"
    if len(body.descrips) >= 1:
        for k, v in body.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    if len(body.related_diseases) >= 1:
        txt = txt + "연관된 질환" + "\n"
        for d in body.related_diseases:
            txt = txt + d + "\n"
    if len(body.related_interventions) >= 1:
        txt = txt + "연관된 시술/수술/검사" + "\n"
        for d in body.related_interventions:
            txt = txt + d + "\n"
    txt = txt + "================================= \n"
#print(txt)

with open("./output/whole/bodies.txt", "w") as text_file:
    text_file.write(txt)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-38119cc872e3> in <module>
#      24 #print(txt)
#      25
# ---> 26 with open("./output/whole/bodies.txt", "w") as text_file:
#      27     text_file.write(txt)
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/whole/bodies.txt'

# %%
txt= ""
for body in bodies:
    txt = txt + "신체명: " + body.name + "\n"
    if len(body.descrips) >= 1:
        for k, v in body.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"

with open("./output/whole/bodies_description.txt", "w") as text_file:
    text_file.write(txt)

# %%
# 항목별 txt 파일
for body in bodies:
    txt= ""
    txt = txt + "신체명: " + body.name + "\n"
    if len(body.descrips) >= 1:
        for k, v in body.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    with open("./output/body_"+ body.name +".txt", "w") as text_file:
        text_file.write(txt)

# %% [markdown]
# # 질환 정보 추출

# %%
class Disease:
    availableTabs=defaultdict() # 현재페이지에 이용가능한 탭과 그 링크
    descrips=defaultdict() # 질환 설명
    healthStory=defaultdict() # 건강이야기
    name="" #질병이름
    related_symptoms=[] #관련증상
    related_diseases=[] # 관련질환
    medDeps=[] #해당 진료과
    synonym="" # 동의어

# %%
# 질환 정보 총 958개  contentId= 31541 - 32499

# www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31541
# http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=32499

diseaseList = []
st = "http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId="

for i in range(958):
        stnew = st + str(31540+ i+1)
        diseaseList.append(stnew)

# %%
# 중간중간 페이지가 비어있는 것으로 확인
print(diseaseList[-29])
# Out:
# http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=32470

# %%
#http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?
#contentId=31541  질환 아이디
#&tabIndex=0  탭 번호 0: 질환설명 / 4:건강이야기
# 질환 정보 총 958개  contentId= 31541 - 32499

def disease_extract(diseaseList):
    diseases = []
    for address in diseaseList: # http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31541
        browser.get(address)
        
        if browser.find_elements_by_class_name("contTitle")[0].text == "()":
            continue
        disease = Disease()
        

        tableIndex= ["4"] # 0: 질환설명 / 4:건강이야기 ------> 의료진 탭과 교육자료는 뺌 

        # 질환 이름
        summaryBox = browser.find_elements_by_class_name("contBox")
        title = summaryBox[0].find_elements_by_class_name("contTitle")
        disease.name = title[0].text
        # 신체 이름 - 끝

        # 증상 / 유사 질환 / 진료과 / 동의어
        summaries = summaryBox[0].find_elements_by_tag_name("dd")
        if len(summaries) >= 1:
            symptoms = summaries[0].find_elements_by_tag_name("a")
            symps = []
            for symptom in symptoms:
                symps.append(symptom.text)
            disease.related_symptoms = symps
            if len(summaries) >= 2:
                diss = summaries[1].find_elements_by_tag_name("a")
                rel_dis = []
                for dis in diss:
                    rel_dis.append(dis.text)
                disease.related_diseases = rel_dis
                if len(summaries) == 3:
                    medDeps = summaries[1].find_elements_by_tag_name("a")
                    deps = []
                    for medDep in medDeps:
                        deps.append(medDep.text)
                    disease.medDeps = deps
                    if len(summaries) == 4:
                        disease.synonym = summaries[3].text
        # 증상 / 유사 질환 / 진료과 / 동의어 - 끝
        
        # 본문 정리 -> 본문 정리는 기본 url로 진행 가능
        ds = {}
        descOuter = browser.find_elements_by_class_name("contDescription")
        definitions = descOuter[0].find_elements_by_tag_name("dt")
        descriptions = descOuter[0].find_elements_by_tag_name("dd")
        if len(definitions) == len(descriptions):
            for defi, des in zip(definitions, descriptions):
                ds[defi.text] = des.text
            disease.descrips = ds
        else:
            print("정의와 설명의 개수가 다름")
        # 본문 정리 - 끝

        # 다음 탭으로 이동
        nextUrl = address + "&tabIndex=" + tableIndex[0]
        browser.get(nextUrl)

        # 건강 이야기 추출
        hl = {}
        healthStories = browser.find_elements_by_class_name("listTypeSec2 photoType widthSmall")
        for healthStory in healthStories:
            titles = browser.find_elements_by_tag_name("dt")
            contents = browser.find_elements_by_tag_name("dd")
            if len(titles) == len(contents):
                for titl, cont in zip(titles, contents):
                    hl[titl.text] = cont.text
                disease.healthStory = hl
            else:
                print("소제목과 내용의 개수가 다름")
        # 건강 이야기 추출 -끝
        
        diseases.append(disease)
        print(disease.name, "완료. 현재 완료한 객체: ", len(diseases))
    return diseases

# %%
diseases = disease_extract(diseaseList)
# Out:
# 대상포진(Herpes zoster) 완료. 현재 완료한 객체:  1
# 백반증(Vitiligo) 완료. 현재 완료한 객체:  2
# 여드름(Acne) 완료. 현재 완료한 객체:  3
# 모낭염(Folliculitis) 완료. 현재 완료한 객체:  4
# 피부암(Skin cancer) 완료. 현재 완료한 객체:  5
# 곰팡이 감염(Fungal infection) 완료. 현재 완료한 객체:  6
# 사마귀(Wart) 완료. 현재 완료한 객체:  7
# 건선(Psoriasis) 완료. 현재 완료한 객체:  8
# 매복 사랑니(Impacted teeth) 완료. 현재 완료한 객체:  9
# 근단 주위 농양(Periapical abscess with sinus) 완료. 현재 완료한 객체:  10
# 치근낭(Radicular cyst) 완료. 현재 완료한 객체:  11
# 만성 치주염(Chronic periodontitis) 완료. 현재 완료한 객체:  12
# 턱크기의 주요 이상(Major anomalies of jaw size) 완료. 현재 완료한 객체:  13
# 턱뼈 성장 이상(Anomalies of the jaw) 완료. 현재 완료한 객체:  14
# 치열 궁 관계 이상(Anomalies of dental arch relationship) 완료. 현재 완료한 객체:  15
# 턱관절 장애(Temporomandibular joint disorders) 완료. 현재 완료한 객체:  16
# 발육성 치성 낭종(Developmental odontogenic cysts) 완료. 현재 완료한 객체:  17
# 턱의 기타 낭(Other cysts of jaw) 완료. 현재 완료한 객체:  18
# 안면 골절(Facial bone fracture) 완료. 현재 완료한 객체:  19
# 대퇴 골절(Fracture of femur) 완료. 현재 완료한 객체:  20
# 경골과 비골 골절(Fracture of tibia & fibula) 완료. 현재 완료한 객체:  21
# 원위 요골과 척골 골절(Fracture of distal radius and ulna) 완료. 현재 완료한 객체:  22
# 슬관절 장애(Internal derangement of knee) 완료. 현재 완료한 객체:  23
# 반월판 연골손상(Tear of meniscus) 완료. 현재 완료한 객체:  24
# 회전근개 증후군(Rotator cuff syndrome) 완료. 현재 완료한 객체:  25
# 손목 수근관 증후군(Carpal tunnel syndrome) 완료. 현재 완료한 객체:  26
# 요추관 협착증(Lumbar spinal stenosis) 완료. 현재 완료한 객체:  27
# 요추 전방전위증(Lumbar spondylolisthesis) 완료. 현재 완료한 객체:  28
# 골절 후 부정 유합, 불유합(Malunion & nonunion of fracture) 완료. 현재 완료한 객체:  29
# 방아쇠 수지(Trigger finger) 완료. 현재 완료한 객체:  30
# 치매(Dementia) 완료. 현재 완료한 객체:  31
# 섬망(Delirium) 완료. 현재 완료한 객체:  32
# 알코올 의존성(Dependance of alcohol) 완료. 현재 완료한 객체:  33
# 조현병(정신분열병)(schizophrenia) 완료. 현재 완료한 객체:  34
# 분열정동 장애(Schizoaffective disorders) 완료. 현재 완료한 객체:  35
# 양극성 장애(Bipolar disorder) 완료. 현재 완료한 객체:  36
# 우울증(Depressive disorder) 완료. 현재 완료한 객체:  37
# 불안 장애(Anxiety disorder) 완료. 현재 완료한 객체:  38
# 공황 장애(Panic disorder) 완료. 현재 완료한 객체:  39
# 적응 장애(Adjustment disorder) 완료. 현재 완료한 객체:  40
# 신체형 장애(Somatic symptom disorder) 완료. 현재 완료한 객체:  41
# 불면증(Insomnia) 완료. 현재 완료한 객체:  42
# 선천성 소장 결손, 폐쇄 및 협착(Congenital absence, atresia and stenosis of intestine) 완료. 현재 완료한 객체:  43
# 맹장염(Appendicitis) 완료. 현재 완료한 객체:  44
# 칸디다성 구내염(Candidal stomatitis) 완료. 현재 완료한 객체:  45
# 항문 폐쇄증(Imperforate anus) 완료. 현재 완료한 객체:  46
# 선천성 거대결장증(Hirschsprung disease) 완료. 현재 완료한 객체:  47
# 총담관 낭(Choledochal cyst) 완료. 현재 완료한 객체:  48
# 림프관종(Lymphangioma) 완료. 현재 완료한 객체:  49
# 갑상선암(Thyroid cancer) 완료. 현재 완료한 객체:  50
# 갑상선 중독증(Thyrotoxicosis) 완료. 현재 완료한 객체:  51
# 당뇨병(Diabetes mellitus) 완료. 현재 완료한 객체:  52
# 디프테리아(Diphtheritia) 완료. 현재 완료한 객체:  53
# 뇌하수체 기능부전(Hypopituitarism) 완료. 현재 완료한 객체:  54
# 뇌하수체 양성 및 악성 신생물(Malignant or benign neoplasm of Pituitary gland) 완료. 현재 완료한 객체:  55
# 부신기능부전(Adrenal insufficiency) 완료. 현재 완료한 객체:  56
# 쿠싱증후군(Cushing's syndrome) 완료. 현재 완료한 객체:  57
# 저혈당증(Hypoglycemia) 완료. 현재 완료한 객체:  58
# 요충증(Enterobiasis) 완료. 현재 완료한 객체:  59
# 감염성 홍반(Erythema infectiosum) 완료. 현재 완료한 객체:  60
# 수족구병(Hand, foot and mouth disease) 완료. 현재 완료한 객체:  61
# 렙토스피라증(Leptospirosis) 완료. 현재 완료한 객체:  62
# 홍역(Measles) 완료. 현재 완료한 객체:  63
# 파라인플루엔자 감염증(Parainfluenza infection) 완료. 현재 완료한 객체:  64
# 광견병(Rabies) 완료. 현재 완료한 객체:  65
# RS바이러스 감염증(RS virus infection) 완료. 현재 완료한 객체:  66
# 골다공증(Osteoporosis) 완료. 현재 완료한 객체:  67
# 풍진(Rubella(German measles)) 완료. 현재 완료한 객체:  68
# 파상풍(Tetanus) 완료. 현재 완료한 객체:  69
# 수두(Varicella (chickenpox)) 완료. 현재 완료한 객체:  70
# 효모균증(Cryptococcosis) 완료. 현재 완료한 객체:  71
# 부신 종양(Adrenal tumor) 완료. 현재 완료한 객체:  72
# 대장균 감염(Escherichia coli (E. coli) infection) 완료. 현재 완료한 객체:  73
# 감염성 근육염(Infective myositis) 완료. 현재 완료한 객체:  74
# 부신암(Adrenal gland cancer) 완료. 현재 완료한 객체:  75
# 인플루엔자(Influenza) 완료. 현재 완료한 객체:  76
# 위 궤양(Gastric ulcer) 완료. 현재 완료한 객체:  77
# 원충성 질환(PROTOZOAL DISEASES) 완료. 현재 완료한 객체:  78
# 슈도모나스 감염(Pseudomonas infection) 완료. 현재 완료한 객체:  79
# 십이지장 궤양(Duodenal ulcer) 완료. 현재 완료한 객체:  80
# 포도상구균 감염(Staphylococcus aureus infection) 완료. 현재 완료한 객체:  81
# 급성 A형 간염(Acute hepatitis A) 완료. 현재 완료한 객체:  82
# 후천성 면역결핍증(Acquired immunodeficiency syndrome) 완료. 현재 완료한 객체:  83
# 방선균증(Actinomycosis) 완료. 현재 완료한 객체:  84
# 철결핍빈혈(Iron deficiency anemia) 완료. 현재 완료한 객체:  85
# 탄저병(Anthrax) 완료. 현재 완료한 객체:  86
# 폐렴(Pneumonia) 완료. 현재 완료한 객체:  87
# 광우병(Bovine spongiform encephalopathy) 완료. 현재 완료한 객체:  88
# 심실 중격 결손(Ventricular septal defect) 완료. 현재 완료한 객체:  89
# 브루셀라증(Brucellosis) 완료. 현재 완료한 객체:  90
# 동맥관 개존증(Patent ductus arteriosus) 완료. 현재 완료한 객체:  91
# 심방 중격 결손(Atrial septal defect) 완료. 현재 완료한 객체:  92
# 방실 중격 결손(Atrioventricular septal defect) 완료. 현재 완료한 객체:  93
# 대동맥궁 단절(Interrupted aortic arch) 완료. 현재 완료한 객체:  94
# 대동맥 협착(Aortic stenosis) 완료. 현재 완료한 객체:  95
# 양대혈관 우심실 기시증(Double outlet right ventricle) 완료. 현재 완료한 객체:  96
# 엡스테인 심기형(Ebstein anomaly) 완료. 현재 완료한 객체:  97
# 전폐정맥연결 이상(Total anomalous pulmonary venous connection) 완료. 현재 완료한 객체:  98
# 대혈관 전위(Transposition of great artery) 완료. 현재 완료한 객체:  99
# 팔로 사 징후(Tetralogy of Fallot with/without PA) 완료. 현재 완료한 객체:  100
# 총동맥간증(Persistent truncus arteriosus) 완료. 현재 완료한 객체:  101
# 온전한 심실 중격을 가진 폐동맥 폐쇄(Pulmonary atresia with intact venticulr septum) 완료. 현재 완료한 객체:  102
# 단심실(Single ventricle) 완료. 현재 완료한 객체:  103
# 양방단실유입증(Double inlet ventricle) 완료. 현재 완료한 객체:  104
# 발육부전성 좌심 증후군(Hypoplastic left heart syndrome) 완료. 현재 완료한 객체:  105
# 심근염(Myocarditis) 완료. 현재 완료한 객체:  106
# 발살바동 동맥류 파열(Ruptured sinus of valsava aneurysm) 완료. 현재 완료한 객체:  107
# 대동맥 협착증(Coarctation of aorta) 완료. 현재 완료한 객체:  108
# 콜레라(Cholera) 완료. 현재 완료한 객체:  109
# 크로이츠펠트-야콥병(Creutzfeldt-Jakob disease) 완료. 현재 완료한 객체:  110
# 동맥간증(Truncus arteriosus) 완료. 현재 완료한 객체:  111
# 반흔 탈장(Incisonal hernia) 완료. 현재 완료한 객체:  112
# 췌장염(Pancreatitis) 완료. 현재 완료한 객체:  113
# 재발성 탈장(Recurrent hernia) 완료. 현재 완료한 객체:  114
# 제대 탈장(Umbilical hernia) 완료. 현재 완료한 객체:  115
# 급성 바이러스성 간염(Acute viral hepatitis) 완료. 현재 완료한 객체:  116
# 한센병(Leprosy) 완료. 현재 완료한 객체:  117
# 리스테리아(Listeria) 완료. 현재 완료한 객체:  118
# 라임병(Lyme disease) 완료. 현재 완료한 객체:  119
# 신종 플루(Novel swine-origin influenza A(H1N1)) 완료. 현재 완료한 객체:  120
# 백일해(Pertussis) 완료. 현재 완료한 객체:  121
# 세균성 이질(Shigellosis) 완료. 현재 완료한 객체:  122
# 스파르가눔증(Sparganosis) 완료. 현재 완료한 객체:  123
# 진행성 위암(Advanced gastric cancer) 완료. 현재 완료한 객체:  124
# 선모충증(Trichinellosis) 완료. 현재 완료한 객체:  125
# 알코올성 간질환(Alcoholic liver disease) 완료. 현재 완료한 객체:  126
# 결핵성 수막염(Tuberculous meningitis) 완료. 현재 완료한 객체:  127
# 황열(Yellow fever) 완료. 현재 완료한 객체:  128
# 메켈 게실(Meckel's diverticulum) 완료. 현재 완료한 객체:  129
# 문맥색전증(Portal vein thrombosis) 완료. 현재 완료한 객체:  130
# 자가면역성 간염(Autoimmune hepatitis) 완료. 현재 완료한 객체:  131
# 무좀(Tinea pedis) 완료. 현재 완료한 객체:  132
# 조갑백선(Tinea unguium) 완료. 현재 완료한 객체:  133
# 총담관 담석(CBD stone) 완료. 현재 완료한 객체:  134
# 만성 B형 간염(Chronic hepatitis B) 완료. 현재 완료한 객체:  135
# 바렛 식도(Barrett's esophagus) 완료. 현재 완료한 객체:  136
# 만성 C형 간염(Chronic hepatitis C) 완료. 현재 완료한 객체:  137
# 조기 위암(Early gastric cancer) 완료. 현재 완료한 객체:  138
# 바이러스성 장염(Viral enteritis(Rota)) 완료. 현재 완료한 객체:  139
# 지방간(Fatty liver) 완료. 현재 완료한 객체:  140
# 위선종(Gastric adenoma) 완료. 현재 완료한 객체:  141
# 간염(Hepatitis) 완료. 현재 완료한 객체:  142
# 소장암(Small bowel cancer) 완료. 현재 완료한 객체:  143
# 대장 용종(Polyp of colon) 완료. 현재 완료한 객체:  144
# 독성 간염(Toxic hepatitis) 완료. 현재 완료한 객체:  145
# 궤양성 대장염(Ulcerative colitis) 완료. 현재 완료한 객체:  146
# 원인을 알 수 없는 열(Fever of unknown origin) 완료. 현재 완료한 객체:  147
# 해외여행 시 주의사항(Travel counseling) 완료. 현재 완료한 객체:  148
# 과호흡 증후군(Hyperventilation syndrome) 완료. 현재 완료한 객체:  149
# 반티 증후군(Banti syndrome) 완료. 현재 완료한 객체:  150
# 버드 키아리 신드롬(Budd-Chiari syndrome) 완료. 현재 완료한 객체:  151
# 아킬레스 건 파열(Acute achilles tendon rupture) 완료. 현재 완료한 객체:  152
# 대퇴골두 무혈관성 괴사(AVN of hip(femoral head)) 완료. 현재 완료한 객체:  153
# 구획 증후군(Compartment syndrome) 완료. 현재 완료한 객체:  154
# 완전 척수 손상(Complete cord injury) 완료. 현재 완료한 객체:  155
# 고관절 이형성증(DDH (developmental dysplasia of the hip)) 완료. 현재 완료한 객체:  156
# 동결견(Frozen shoulder) 완료. 현재 완료한 객체:  157
# 결절종(Ganglion) 완료. 현재 완료한 객체:  158
# 요통(Low back pain) 완료. 현재 완료한 객체:  159
# 골육종(Osteosarcoma) 완료. 현재 완료한 객체:  160
# 요근 농양(Psoas abscess) 완료. 현재 완료한 객체:  161
# 간농양(Liver abscess) 완료. 현재 완료한 객체:  162
# 재발성 견관절 전방 탈구(Recurrent Anterior Glenohumeral Dislocation) 완료. 현재 완료한 객체:  163
# 횡문근육종(Rhabdomyosarcoma) 완료. 현재 완료한 객체:  164
# 피로 골절(Stress fracture) 완료. 현재 완료한 객체:  165
# 건 손상(Tendon injury) 완료. 현재 완료한 객체:  166
# 관절염(Arthritis) 완료. 현재 완료한 객체:  167
# 척추 골수염(Vertebral osteomyelitis) 완료. 현재 완료한 객체:  168
# 변형성 고관절증(Coxarthrosis) 완료. 현재 완료한 객체:  169
# 원판형 반월상연골(Discoid meniscus) 완료. 현재 완료한 객체:  170
# 반달연골 이상(Meniscus derangements) 완료. 현재 완료한 객체:  171
# 골수염(Osteomyelitis) 완료. 현재 완료한 객체:  172
# 결핵성 골수염(Tuberculous osteomyelitis) 완료. 현재 완료한 객체:  173
# 골괴사(Osteonecrosis) 완료. 현재 완료한 객체:  174
# 바이러스성 뇌수막염(Viral meningitis) 완료. 현재 완료한 객체:  175
# 병리적 골절(Pathological fracture) 완료. 현재 완료한 객체:  176
# 박테리아성 뇌수막염(Bacterial meningitis) 완료. 현재 완료한 객체:  177
# 척추병증(Spondylopathies) 완료. 현재 완료한 객체:  178
# 급성 위장염(Acute gastroenteritis) 완료. 현재 완료한 객체:  179
# 위장관 결핵(Gastrointestinal tuberculosis) 완료. 현재 완료한 객체:  180
# 결핵성 복막염(Tuberculous peritonitis) 완료. 현재 완료한 객체:  181
# 아킬레스 건염(Achilles' tendonitis) 완료. 현재 완료한 객체:  182
# 베이커 낭종(Baker's cyst) 완료. 현재 완료한 객체:  183
# 내반슬(Bow leg) 완료. 현재 완료한 객체:  184
# 소건막류(Bunionette) 완료. 현재 완료한 객체:  185
# 요족(Cavus foot) 완료. 현재 완료한 객체:  186
# 복합 부위 통증 증후군(Complex regional pain syndrome) 완료. 현재 완료한 객체:  187
# 매독(Syphilis) 완료. 현재 완료한 객체:  188
# 패혈성 관절염(Septic arthtritis) 완료. 현재 완료한 객체:  189
# 급성 방광염(Acute cystitis) 완료. 현재 완료한 객체:  190
# 급성 신우신염(Acute pyelonephritis) 완료. 현재 완료한 객체:  191
# 듀피트렌 구축(Dupuytren's contracture) 완료. 현재 완료한 객체:  192
# 내연골종(Enchondroma) 완료. 현재 완료한 객체:  193
# 경부 림프절염(Cervical lymphadenitis) 완료. 현재 완료한 객체:  194
# 결핵성 임파선염(Tuberculous lymphadenitis) 완료. 현재 완료한 객체:  195
# 지역사회성 폐렴(Community acquired pneumonia) 완료. 현재 완료한 객체:  196
# 병원 감염성 폐렴(Hospital acquired pneumonia (HAP)) 완료. 현재 완료한 객체:  197
# 속립성 결핵(Miliary tuberculosis) 완료. 현재 완료한 객체:  198
# 말라리아(Malaria) 완료. 현재 완료한 객체:  199
# 털진드기병(Scrub typhus) 완료. 현재 완료한 객체:  200
# 증상이 없는 HIV 감염(HIV infection, asymptomatic) 완료. 현재 완료한 객체:  201
# 말기 신질환(End stage renal disease) 완료. 현재 완료한 객체:  202
# 하지 정맥류(Varicose veins) 완료. 현재 완료한 객체:  203
# 심부정맥 색전증(Deep vein thrombosis) 완료. 현재 완료한 객체:  204
# 동맥색전증 및 혈전증(Arterial embolism and thrombosis) 완료. 현재 완료한 객체:  205
# 뇌동맥 폐쇄(Occlusion of cerebral artery) 완료. 현재 완료한 객체:  206
# 죽상경화증(Atherosclerosis) 완료. 현재 완료한 객체:  207
# 당뇨병성 족부 질환(DM foot ulcer) 완료. 현재 완료한 객체:  208
# 동맥류(Other aneurysm) 완료. 현재 완료한 객체:  209
# 혈관염(Vasculitis) 완료. 현재 완료한 객체:  210
# 욕창(Skin defect (and/or) soft tissue defect) 완료. 현재 완료한 객체:  211
# 흉터(Scar) 완료. 현재 완료한 객체:  212
# 피부의 양성 종양(Benign skin tumor) 완료. 현재 완료한 객체:  213
# 두개유합증(Craniosynostosis) 완료. 현재 완료한 객체:  214
# 구순열(Cleft lip) 완료. 현재 완료한 객체:  215
# 구개열(Cleft palate) 완료. 현재 완료한 객체:  216
# 안면 마비(Facial palsy) 완료. 현재 완료한 객체:  217
# 안면 비대칭(Facial asymmetry) 완료. 현재 완료한 객체:  218
# 두개 안면 부조화(Craniofacial dysharmony) 완료. 현재 완료한 객체:  219
# 노화된 얼굴(Aging face) 완료. 현재 완료한 객체:  220
# 비 변형(Nose deformity) 완료. 현재 완료한 객체:  221
# 취한증(Osmidrosis) 완료. 현재 완료한 객체:  222
# 선천성 손 기형(Congenital hand anomaly) 완료. 현재 완료한 객체:  223
# 수부 외상(Hand trauma) 완료. 현재 완료한 객체:  224
# 직장의 양성 종양(Rectum, benign tumor) 완료. 현재 완료한 객체:  225
# 치핵(Hemorrhoids) 완료. 현재 완료한 객체:  226
# 항문 열구(Anal fissure) 완료. 현재 완료한 객체:  227
# 항문 주위 농양(Perianal abscess) 완료. 현재 완료한 객체:  228
# 항문 누공(Anal fistula) 완료. 현재 완료한 객체:  229
# 대장의 양성 종양(Benign colon tumor) 완료. 현재 완료한 객체:  230
# 게실 질환(Diverticular disease) 완료. 현재 완료한 객체:  231
# 급성림프모구백혈병(Acute lymphoblastic leukemia) 완료. 현재 완료한 객체:  232
# 급성골수성백혈병(Acute myeloid leukemia) 완료. 현재 완료한 객체:  233
# 만성림프구백혈병(Chronic lymphocytic leukemia) 완료. 현재 완료한 객체:  234
# 만성골수백혈병(Chronic myeloid leukemia) 완료. 현재 완료한 객체:  235
# 한랭글로불린혈증(Cryoglobulinemia) 완료. 현재 완료한 객체:  236
# 단세포군감마글로불린병증(Monoclonal gammopathy of undetermined significance) 완료. 현재 완료한 객체:  237
# 고립성 골수종(Solitary myeloma) 완료. 현재 완료한 객체:  238
# 아밀로이드증(Amyloidosis) 완료. 현재 완료한 객체:  239
# 재생불량빈혈(Aplastic anemia) 완료. 현재 완료한 객체:  240
# 골수로성 빈혈(Myelophthisic anemia) 완료. 현재 완료한 객체:  241
# 순수적혈구무형성(Pure red cell aplasia) 완료. 현재 완료한 객체:  242
# 자가면역용혈질환(Autoimmune hemolytic disease) 완료. 현재 완료한 객체:  243
# 약물 유발성 자가면역성 용혈성 빈혈(Drug-induced autoimmune hemolytic anemia) 완료. 현재 완료한 객체:  244
# 유전구형적혈구증(Hereditary spherocytosis) 완료. 현재 완료한 객체:  245
# 미세혈관병용혈빈혈(Microangiopathic hemolytic anemia) 완료. 현재 완료한 객체:  246
# 발작성야간혈색뇨(Paroxysmal nocturnal hemoglobinuria) 완료. 현재 완료한 객체:  247
# 지중해빈혈(Thalassemia) 완료. 현재 완료한 객체:  248
# 파종혈관내응고(Diffuse or disseminated intravascular coagulation) 완료. 현재 완료한 객체:  249
# 골수증식종양(Myeloproliferative neoplasm) 완료. 현재 완료한 객체:  250
# 두드러기(Urticaria) 완료. 현재 완료한 객체:  251
# 신부전(Renal failure) 완료. 현재 완료한 객체:  252
# 소아 류마티스 관절염(Juvenile rheumatoid arthritis) 완료. 현재 완료한 객체:  253
# 헤노호 쉰라인 자반증(Henoch-Schonlein purpura) 완료. 현재 완료한 객체:  254
# 혈뇨(Hematuria) 완료. 현재 완료한 객체:  255
# 사구체신염(Glomerulonephritis) 완료. 현재 완료한 객체:  256
# 갑상선 결절(Thyroid nodule) 완료. 현재 완료한 객체:  257
# 구루병(Rickets) 완료. 현재 완료한 객체:  258
# 부갑상선기능저하증(Hypoparathyroidism) 완료. 현재 완료한 객체:  259
# 요붕증(Diabetes insipidus) 완료. 현재 완료한 객체:  260
# 성선기능저하증(Hypogonadism) 완료. 현재 완료한 객체:  261
# 성장호르몬 결핍증(Growth hormone deficiency) 완료. 현재 완료한 객체:  262
# 비만(Obesity) 완료. 현재 완료한 객체:  263
# 급성 기관지염(Acute bronchitis) 완료. 현재 완료한 객체:  264
# 천식(Asthma) 완료. 현재 완료한 객체:  265
# 재발성 천명(Recurrent wheeze) 완료. 현재 완료한 객체:  266
# 만성 폐질환(Chronic lung disease) 완료. 현재 완료한 객체:  267
# 기관지확장증(Bronchiectasis) 완료. 현재 완료한 객체:  268
# 면역결핍증(Immunodeficiency disease) 완료. 현재 완료한 객체:  269
# 상기도 감염(Upper respiratory infections) 완료. 현재 완료한 객체:  270
# 과다호산구증가증(Hypereosinophilia) 완료. 현재 완료한 객체:  271
# 자궁경부암(Cervical cancer) 완료. 현재 완료한 객체:  272
# 자궁내막암(Endometrial cancer) 완료. 현재 완료한 객체:  273
# 난소암(Ovarian cancer) 완료. 현재 완료한 객체:  274
# 자궁 상피내 암종(Carcinoma in situ of Cervix) 완료. 현재 완료한 객체:  275
# 자궁의 평활근종(Leiomyoma of uterus) 완료. 현재 완료한 객체:  276
# 난소의 양성 종양(Benign ovary tumor) 완료. 현재 완료한 객체:  277
# 난소 낭종(Ovarian cysts) 완료. 현재 완료한 객체:  278
# 골반 염증성 질환(Pelvic inflammatory disease) 완료. 현재 완료한 객체:  279
# 자궁내막 이상증식증(Endometrial hyperplasia) 완료. 현재 완료한 객체:  280
# 급성 질염(Acute vaginitis) 완료. 현재 완료한 객체:  281
# 자궁내막증(Endometriosis) 완료. 현재 완료한 객체:  282
# 선근증, 자궁선종(Adenomyosis) 완료. 현재 완료한 객체:  283
# 자궁 탈출증(Uterine Prolapse) 완료. 현재 완료한 객체:  284
# 자궁내막 용종(Polyp of endometrium) 완료. 현재 완료한 객체:  285
# 무월경(Amenorrhea) 완료. 현재 완료한 객체:  286
# 다낭성 난소증후군(Polycystic ovary syndrome) 완료. 현재 완료한 객체:  287
# 다태아(Multifetal pregnancy) 완료. 현재 완료한 객체:  288
# 태반 조기 박리(Abruptio placenta) 완료. 현재 완료한 객체:  289
# 아두골반 불균형(Cephalopelvic disproportion) 완료. 현재 완료한 객체:  290
# 임신성 당뇨병(Gestational diabetes) 완료. 현재 완료한 객체:  291
# 가진통(False labor) 완료. 현재 완료한 객체:  292
# 이상 태위(Malpresentation of fetus) 완료. 현재 완료한 객체:  293
# 전치 태반(Placenta previa) 완료. 현재 완료한 객체:  294
# 만기 정상 분만(Normal full term spontaneous delivery) 완료. 현재 완료한 객체:  295
# 조산(Prematurity delivery) 완료. 현재 완료한 객체:  296
# 자궁 내 성장 지연(Intrauterine growth retardation) 완료. 현재 완료한 객체:  297
# 자궁경관무력증(Incompetent internal os of cervix) 완료. 현재 완료한 객체:  298
# 조기 양막 파열(Premature rupture of membranes) 완료. 현재 완료한 객체:  299
# 임신성 고혈압(Pregnancy-induced hypertension) 완료. 현재 완료한 객체:  300
# 폐결핵(Pulmonary tuberculosis) 완료. 현재 완료한 객체:  301
# 미만성 간질성 폐질환(Diffuse Interstitial lung disease) 완료. 현재 완료한 객체:  302
# 폐기종(Emphysema) 완료. 현재 완료한 객체:  303
# 객혈(Hemoptysis) 완료. 현재 완료한 객체:  304
# 발작(Seizure) 완료. 현재 완료한 객체:  305
# 두통(Headache) 완료. 현재 완료한 객체:  306
# 근육병(Myopathy) 완료. 현재 완료한 객체:  307
# 모야모야병(Moyamoya disease) 완료. 현재 완료한 객체:  308
# 내상과염(Golf Elbow) 완료. 현재 완료한 객체:  309
# 망치족지(Hammer toe) 완료. 현재 완료한 객체:  310
# 이소성 골화증(Heterotopic Ossification) 완료. 현재 완료한 객체:  311
# 외반슬(Knock-knee) 완료. 현재 완료한 객체:  312
# 슬개건염(Patellar tendinitis) 완료. 현재 완료한 객체:  313
# 노인성 척추후만증(Senile Kyphosis) 완료. 현재 완료한 객체:  314
# 주관절 외상과염(Tennis Elbow) 완료. 현재 완료한 객체:  315
# 건초염(Tenosynovitis) 완료. 현재 완료한 객체:  316
# 일과성 고관절 활액막염(Transient synovitis of hip) 완료. 현재 완료한 객체:  317
# 횡단성 척수염(Transverse myelitis) 완료. 현재 완료한 객체:  318
# 거북목 증후군(Turtle neck syndrome) 완료. 현재 완료한 객체:  319
# 청신경초종(Vestibular schwannoma) 완료. 현재 완료한 객체:  320
# 뇌성 마비(Cerebral palsy) 완료. 현재 완료한 객체:  321
# 경추 추간판 탈출증(Cervical HIVD) 완료. 현재 완료한 객체:  322
# 군발성 두통 증후군(Cluster headache syndrome) 완료. 현재 완료한 객체:  323
# 자간증(Eclampsia) 완료. 현재 완료한 객체:  324
# 악성 신경교종(Malignant Glioma) 완료. 현재 완료한 객체:  325
# 행동 및 충동 장애(Disruptive, impulse-control and conduct disorders) 완료. 현재 완료한 객체:  326
# 뇌하수체의 악성 신생물(Malignant neoplasm of Pituitary gland) 완료. 현재 완료한 객체:  327
# 수막종(Meningioma) 완료. 현재 완료한 객체:  328
# 편두통(Migraine) 완료. 현재 완료한 객체:  329
# 신경종(Neuroma) 완료. 현재 완료한 객체:  330
# 병적 방화(Pathological fire-setting) 완료. 현재 완료한 객체:  331
# 외상 후 스트레스 장애(Post-traumatic stress disorder) 완료. 현재 완료한 객체:  332
# 수면 무호흡증(Sleep apnea) 완료. 현재 완료한 객체:  333
# 근육 긴장성 두통(Tension-type headache) 완료. 현재 완료한 객체:  334
# 발모벽(Trichotillomania) 완료. 현재 완료한 객체:  335
# 삼차 신경병증(Trigeminal neuralgia) 완료. 현재 완료한 객체:  336
# 보행 운동 장애(Abnormalities of gait and mobility) 완료. 현재 완료한 객체:  337
# 섭식 장애(Eating disorder) 완료. 현재 완료한 객체:  338
# 주의력결핍 과잉행동장애(Attention-Deficit Hyperactivity Disorder) 완료. 현재 완료한 객체:  339
# 다발성 신경병증(Polyneuropathy) 완료. 현재 완료한 객체:  340
# 대상포진후 신경통(Postzoster neuralgia) 완료. 현재 완료한 객체:  341
# 자간전증(Pre-eclampsia) 완료. 현재 완료한 객체:  342
# 신경근병증(Radiculopathy) 완료. 현재 완료한 객체:  343
# 수면 장애(Sleep Disorder) 완료. 현재 완료한 객체:  344
# 외상성 경막하 출혈(Traumatic subdural hemorrhage) 완료. 현재 완료한 객체:  345
# 광장공포증(Agoraphobia) 완료. 현재 완료한 객체:  346
# 반사회성 인격장애(Antisocial Personality Disorder) 완료. 현재 완료한 객체:  347
# 실어증(Aphasia) 완료. 현재 완료한 객체:  348
# 자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder) 완료. 현재 완료한 객체:  349
# 각기병(Beriberi) 완료. 현재 완료한 객체:  350
# 망상 장애(Delusional disorder) 완료. 현재 완료한 객체:  351
# 해리 장애(Dissociative disorder) 완료. 현재 완료한 객체:  352
# 변비(Constipation) 완료. 현재 완료한 객체:  353
# 난독증(Dyslexia) 완료. 현재 완료한 객체:  354
# 기분부전증(Dysthymia) 완료. 현재 완료한 객체:  355
# 설인신경통(Glossopharyngeal neuralgia) 완료. 현재 완료한 객체:  356
# 길랑-바레 증후군(Guillain-Barre Syndrome) 완료. 현재 완료한 객체:  357
# 변실금(Fecal incontinence) 완료. 현재 완료한 객체:  358
# 지간 신경종(Interdigital neuroma) 완료. 현재 완료한 객체:  359
# 인터넷 중독(Internet addiction) 완료. 현재 완료한 객체:  360
# 얼렌 증후군(Irlen syndrome) 완료. 현재 완료한 객체:  361
# 지적장애(Intellectual disability) 완료. 현재 완료한 객체:  362
# 뮌하우젠 증후군(Munchausen's syndrome) 완료. 현재 완료한 객체:  363
# 골수섬유증(Myelofibrosis) 완료. 현재 완료한 객체:  364
# 기면증(Narcolepsy) 완료. 현재 완료한 객체:  365
# 복막염(Peritonitis) 완료. 현재 완료한 객체:  366
# 후두 신경통(Occipital Neuralgia) 완료. 현재 완료한 객체:  367
# 편집성 인격장애(Paranoid personality disorder) 완료. 현재 완료한 객체:  368
# 성도착증(Paraphilia) 완료. 현재 완료한 객체:  369
# 반응성 애착장애(Reactive Attachment Disorder) 완료. 현재 완료한 객체:  370
# 하지불안증후군(Restless Legs Syndrome) 완료. 현재 완료한 객체:  371
# 좌골신경통(Sciatica) 완료. 현재 완료한 객체:  372
# 성기능장애(Sexual dysfunctions) 완료. 현재 완료한 객체:  373
# 사회공포증(Sociophobia) 완료. 현재 완료한 객체:  374
# 수면보행증(Somnambulism) 완료. 현재 완료한 객체:  375
# 말더듬이(Stuttering) 완료. 현재 완료한 객체:  376
# 지주막하 출혈(Subarachnoid hemorrhage) 완료. 현재 완료한 객체:  377
# 틱장애(Tic) 완료. 현재 완료한 객체:  378
# 의상도착증(Transvestic fetishism) 완료. 현재 완료한 객체:  379
# 바르톨린샘의 고름집(Abscess of Bartholin's gland) 완료. 현재 완료한 객체:  380
# 양수 색전증(Amniotic fluid embolism) 완료. 현재 완료한 객체:  381
# 칸디다성 외음질염(Candidal vulvovaginitis) 완료. 현재 완료한 객체:  382
# 융모막암종(Choriocarcinoma) 완료. 현재 완료한 객체:  383
# 첨형 콘딜로마(Condyloma accuminatum) 완료. 현재 완료한 객체:  384
# 여성 불임(Female infertility) 완료. 현재 완료한 객체:  385
# 외음질의 이물(Foreign body in vulva and vagina) 완료. 현재 완료한 객체:  386
# 회음 괴저(Fournier's gangrene) 완료. 현재 완료한 객체:  387
# 포상기태(Hydatidiform mole) 완료. 현재 완료한 객체:  388
# 유방통(Mastodynia) 완료. 현재 완료한 객체:  389
# 폐경기 및 여성의 갱년기 상태(Menopausal and female climacteric states) 완료. 현재 완료한 객체:  390
# 원발성 월경곤란(Primary dysmenorrhea) 완료. 현재 완료한 객체:  391
# 노인성 질염(Senile (atrophic) vaginitis) 완료. 현재 완료한 객체:  392
# 트리코모나스증(Trichomoniasis) 완료. 현재 완료한 객체:  393
# 비정상적 자궁, 질 출혈(Abnormal uterine and vaginal bleeding) 완료. 현재 완료한 객체:  394
# 유산(Abortion) 완료. 현재 완료한 객체:  395
# 유산 후 계속되는 임신(다태)(Continuing pregnancy after abortion) 완료. 현재 완료한 객체:  396
# 난소, 난관 이상(Disorders of ovary, fallopian tube) 완료. 현재 완료한 객체:  397
# 자궁 경부의 이형성증(Dysplasia of cervix uteri) 완료. 현재 완료한 객체:  398
# 자궁외 임신(Ectopic pregnancy) 완료. 현재 완료한 객체:  399
# 계류 유산(Missed abortion) 완료. 현재 완료한 객체:  400
# 자궁의 비염증성 장애(Noninflammatory disorders of uterus) 완료. 현재 완료한 객체:  401
# 양수과소증(Oligohydramnios) 완료. 현재 완료한 객체:  402
# 회음 열상(Perineal laceration) 완료. 현재 완료한 객체:  403
# 분만 후 출혈(Postpartum hemorrhage) 완료. 현재 완료한 객체:  404
# 조기 진통(Preterm labour) 완료. 현재 완료한 객체:  405
# 만성 중이염(Chronic otitis media) 완료. 현재 완료한 객체:  406
# 삼출성 중이염(Otitis media with effusion) 완료. 현재 완료한 객체:  407
# 설소대 단축증(Tongue tie) 완료. 현재 완료한 객체:  408
# 낭포성 히그로마(Cystic hygroma) 완료. 현재 완료한 객체:  409
# 난산(Dystocia) 완료. 현재 완료한 객체:  410
# 태아 알코올 증후군(Fetal alcohol syndrome) 완료. 현재 완료한 객체:  411
# 아데노이드의 비대를 동반한 편도의 비대(Hypertrophy of tonsils with hypertrophy of adenoids) 완료. 현재 완료한 객체:  412
# 과다월경(Hypermenorrhea) 완료. 현재 완료한 객체:  413
# 후두암(Larynx cancer) 완료. 현재 완료한 객체:  414
# 칼만 증후군(Kallmann syndrome) 완료. 현재 완료한 객체:  415
# 비중격 만곡(Nasal septal deviation) 완료. 현재 완료한 객체:  416
# 만성 부비동염(Chronic rhinosinusitis) 완료. 현재 완료한 객체:  417
# 희발월경(Oligomenorrhea) 완료. 현재 완료한 객체:  418
# 성대와 후두 용종(Polyps of vocal cord and larynx) 완료. 현재 완료한 객체:  419
# 성대와 후두 결절(Nodules of vocal cord and larynx) 완료. 현재 완료한 객체:  420
# 배란통(Ovulation pain) 완료. 현재 완료한 객체:  421
# 감각신경성 난청(Sensorineural hearing loss) 완료. 현재 완료한 객체:  422
# 산후 우울증(Postpartum depression) 완료. 현재 완료한 객체:  423
# 급성 신부전(Acute renal failure) 완료. 현재 완료한 객체:  424
# 산후 갑상선염(Postpartum thyroiditis) 완료. 현재 완료한 객체:  425
# 만성 신부전(Chronic renal failure) 완료. 현재 완료한 객체:  426
# 월경전 증후군(Premenstrual syndrome) 완료. 현재 완료한 객체:  427
# 산욕열(Puerperal fever) 완료. 현재 완료한 객체:  428
# 급성 간질성 신염(Acute tubulo-interstitial nephritis) 완료. 현재 완료한 객체:  429
# 낭성 신장 질환(Cystic kidney disease) 완료. 현재 완료한 객체:  430
# 부가지(Accessory toe) 완료. 현재 완료한 객체:  431
# 무지외반증(Hallux valgus) 완료. 현재 완료한 객체:  432
# 신증후군(Nephrotic syndrome) 완료. 현재 완료한 객체:  433
# 지방종(Lipoma) 완료. 현재 완료한 객체:  434
# 매몰귀(Cryptotia) 완료. 현재 완료한 객체:  435
# 파킨슨병(Parkinson's disease) 완료. 현재 완료한 객체:  436
# 양안격리증(Hypertelorism) 완료. 현재 완료한 객체:  437
# 비정형 파킨슨 증후군(Atypical Parkinsonism) 완료. 현재 완료한 객체:  438
# 소이증(Microtia) 완료. 현재 완료한 객체:  439
# 돌출귀(Prominent Ear) 완료. 현재 완료한 객체:  440
# 이차성 파킨슨증(Other parkinsonism) 완료. 현재 완료한 객체:  441
# 기관지폐 형성이상(Bronchopulmonary dysplasia) 완료. 현재 완료한 객체:  442
# 근육 긴장 이상증(Dystonia) 완료. 현재 완료한 객체:  443
# 선천성 사경(Congenital (sternomastoid) torticollis) 완료. 현재 완료한 객체:  444
# 선천성 수신증(Congenital hydronephrosis) 완료. 현재 완료한 객체:  445
# 떨림, 진전(Tremor) 완료. 현재 완료한 객체:  446
# 선천성 편평발(Congenital pes planus [flat foot]) 완료. 현재 완료한 객체:  447
# 일과성 뇌허혈증(Transient cerebral ischemia) 완료. 현재 완료한 객체:  448
# 뇌경색(Cerebral infarction) 완료. 현재 완료한 객체:  449
# 횡격막 탈장(Diaphragmatic hernia) 완료. 현재 완료한 객체:  450
# 야뇨증(Enuresis) 완료. 현재 완료한 객체:  451
# 알츠하이머병(Alzheimer's disease) 완료. 현재 완료한 객체:  452
# 샅(서혜)육아종(Granuloma inguinale) 완료. 현재 완료한 객체:  453
# 혈관성 치매(Vascular dementia) 완료. 현재 완료한 객체:  454
# 영아 비대성 유문협착증(IHPS (infantile hypertrophic pyloric stenosis)) 완료. 현재 완료한 객체:  455
# 경미한 인지장애(Mild cognitive impairment) 완료. 현재 완료한 객체:  456
# 신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn) 완료. 현재 완료한 객체:  457
# 다발성 경화증(Multiple sclerosis) 완료. 현재 완료한 객체:  458
# 아동 학대(Abuse of Child) 완료. 현재 완료한 객체:  459
# 중증 근무력증(Myasthenia gravis) 완료. 현재 완료한 객체:  460
# 운동 신경 질환(Motor neuron disease) 완료. 현재 완료한 객체:  461
# 척수병증(Myelopathy) 완료. 현재 완료한 객체:  462
# 전이 암(Metastatic cancer) 완료. 현재 완료한 객체:  463
# 성홍열(Scarlet fever) 완료. 현재 완료한 객체:  464
# 폐 전이(Lung Metastasis) 완료. 현재 완료한 객체:  465
# 잠재성 이분 척추(Spina bifida occulta) 완료. 현재 완료한 객체:  466
# 악성 흉막 삼출(Malignant pleural effusion) 완료. 현재 완료한 객체:  467
# 췌장 전이암(Pancreatic metastasis) 완료. 현재 완료한 객체:  468
# 전이성 신장암(Kidney, cancer, metastatic) 완료. 현재 완료한 객체:  469
# 선천성 기형(Congenital malformation) 완료. 현재 완료한 객체:  470
# 신우요관암의 전이(Metastatic renal pelvis cancer) 완료. 현재 완료한 객체:  471
# 요관 결석(Ureteral stone) 완료. 현재 완료한 객체:  472
# 연부조직 전이(Soft tissue metastatic) 완료. 현재 완료한 객체:  473
# 서혜부 탈장(Inguinal hernia) 완료. 현재 완료한 객체:  474
# 신생아 황달(Neonatal jaundice) 완료. 현재 완료한 객체:  475
# 알포트 증후군(Alports syndrome) 완료. 현재 완료한 객체:  476
# 신생아 경련(Convulsions of newborn) 완료. 현재 완료한 객체:  477
# 영아 산통(Infantile Colic) 완료. 현재 완료한 객체:  478
# 척수수막류(Myelomeningoceles) 완료. 현재 완료한 객체:  479
# 신생아 가사(Neonatal asphyxia) 완료. 현재 완료한 객체:  480
# 배꼽염(Omphalitis) 완료. 현재 완료한 객체:  481
# 소아마비(Polio) 완료. 현재 완료한 객체:  482
# 신생아 호흡곤란증후군(Neonatal respiratory distress syndrome) 완료. 현재 완료한 객체:  483
# 라이 증후군(Reye syndrome) 완료. 현재 완료한 객체:  484
# 기형종(Teratoma) 완료. 현재 완료한 객체:  485
# 고환 여성화 증후군(Testicular feminization syndrome) 완료. 현재 완료한 객체:  486
# 급성 충수염(Acute appendicitis) 완료. 현재 완료한 객체:  487
# 복수(Ascites) 완료. 현재 완료한 객체:  488
# 석회화 담낭(Porcelain GB) 완료. 현재 완료한 객체:  489
# 셀리악병(Celiac disease) 완료. 현재 완료한 객체:  490
# 소장의 혈관 장애(Vascular disorders of intestine) 완료. 현재 완료한 객체:  491
# 소화불량(Dyspepsia) 완료. 현재 완료한 객체:  492
# 스핑고 지질증(Other sphingolipidosis) 완료. 현재 완료한 객체:  493
# 식도 정맥류(Esophageal varices) 완료. 현재 완료한 객체:  494
# 식도암(Esophageal cancer) 완료. 현재 완료한 객체:  495
# 식도염(Esophagitis) 완료. 현재 완료한 객체:  496
# 식도의 평활근종(Leiomyoma of esophagus) 완료. 현재 완료한 객체:  497
# 십이지장염(Duodenitis) 완료. 현재 완료한 객체:  498
# 아메바성 간농양(Amebic liver abscess) 완료. 현재 완료한 객체:  499
# 위 정맥류(Gastric varices) 완료. 현재 완료한 객체:  500
# 위경련(Stomach cramp) 완료. 현재 완료한 객체:  501
# 위용종(Gastric polyp) 완료. 현재 완료한 객체:  502
# 위장관 출혈(Gastrointestinal hemorrhage) 완료. 현재 완료한 객체:  503
# 장유착(Intestine adhesions) 완료. 현재 완료한 객체:  504
# 자극성 장 증후군(Irritable bowel syndrome) 완료. 현재 완료한 객체:  505
# 장중첩증(Intussusception) 완료. 현재 완료한 객체:  506
# 항문 및 직장의 궤양(Ulcer of anus and rectum) 완료. 현재 완료한 객체:  507
# 장폐색(Intestinal obstruction) 완료. 현재 완료한 객체:  508
# 탈항(Anal prolapse) 완료. 현재 완료한 객체:  509
# 췌장암(Pancreatic cancer) 완료. 현재 완료한 객체:  510
# 핵황달(Kernicterus) 완료. 현재 완료한 객체:  511
# 동상(Frostbite) 완료. 현재 완료한 객체:  512
# 고콜레스테롤혈증(Pure hypercholesterolemia) 완료. 현재 완료한 객체:  513
# 냉방병(Air-conditioningitis) 완료. 현재 완료한 객체:  514
# 만성 피로 증후군(Chronic Fatigue Syndrome) 완료. 현재 완료한 객체:  515
# 대사 증후군(Metabolic syndrome) 완료. 현재 완료한 객체:  516
# 새집 증후군(Sick building syndrome) 완료. 현재 완료한 객체:  517
# 잠수병(Diver's disease) 완료. 현재 완료한 객체:  518
# 건강염려증(Hypochondriasis) 완료. 현재 완료한 객체:  519
# 수족냉증(Coldness of hands and feet) 완료. 현재 완료한 객체:  520
# 유당분해효소결핍증(Lactose intolerance) 완료. 현재 완료한 객체:  521
# 급성 담낭염(Acute cholecystitis) 완료. 현재 완료한 객체:  522
# 간성 뇌증(Hepatic encephalopathy) 완료. 현재 완료한 객체:  523
# 화농성 간농양(Pyogenic liver abscess) 완료. 현재 완료한 객체:  524
# 경화성 담관염(Sclerosing cholangitis) 완료. 현재 완료한 객체:  525
# 급성 B형 간염(Acute hepatitis B) 완료. 현재 완료한 객체:  526
# 급성 C형 간염(Acute hepatitis C) 완료. 현재 완료한 객체:  527
# 원발성 담즙성 경화증(Primary Biliary cirrhosis) 완료. 현재 완료한 객체:  528
# 만성 담낭염(Chronic cholecystitis) 완료. 현재 완료한 객체:  529
# 대장염(Colitis) 완료. 현재 완료한 객체:  530
# 헬리코박터균 감염(Helicobacter pylori infection) 완료. 현재 완료한 객체:  531
# 간 혈관종(Hepatic hemangioma) 완료. 현재 완료한 객체:  532
# 간신 증후군(Hepatorenal syndrome) 완료. 현재 완료한 객체:  533
# 카롤리병(Caroli’s disease) 완료. 현재 완료한 객체:  534
# 간디스토마(Clonorchisis sinensis) 완료. 현재 완료한 객체:  535
# 덤핑 증후군(Dumping syndrome) 완료. 현재 완료한 객체:  536
# 말로리-바이스 증후군(Mallory-weiss Syndrome) 완료. 현재 완료한 객체:  537
# 항문소양증(Pruritusani) 완료. 현재 완료한 객체:  538
# 위막성 대장염(Pseudomembranous colitis) 완료. 현재 완료한 객체:  539
# 단장 증후군(Short Bowel Syndrome) 완료. 현재 완료한 객체:  540
# 복부 대동맥류(Abdominal aortic Aneurysm) 완료. 현재 완료한 객체:  541
# 급성 심근경색증(Acute myocardial infarction) 완료. 현재 완료한 객체:  542
# 동정맥루 기능부전(AVF malfuction) 완료. 현재 완료한 객체:  543
# 악성 중피종(Malignant mesothelioma) 완료. 현재 완료한 객체:  544
# 심낭 압전(Cardiac tamponade) 완료. 현재 완료한 객체:  545
# 천추골 골절(sacral fracture) 완료. 현재 완료한 객체:  546
# 수정대혈관 전위(Corrected TGA) 완료. 현재 완료한 객체:  547
# 염좌(sprain) 완료. 현재 완료한 객체:  548
# 오래된 심근경색증(Old myocardial infarction) 완료. 현재 완료한 객체:  549
# 편도결석(tonsillolith) 완료. 현재 완료한 객체:  550
# 카포시 육종(Kaposi's sarcoma) 완료. 현재 완료한 객체:  551
# 임파선염(Lymphadenitis) 완료. 현재 완료한 객체:  552
# 결절성 다발동맥염(Polyarteritis nodosa) 완료. 현재 완료한 객체:  553
# 춘곤증(spring fatigue) 완료. 현재 완료한 객체:  554
# 괴혈병(scurvy) 완료. 현재 완료한 객체:  555
# 조로증(progeria) 완료. 현재 완료한 객체:  556
# 아메바성 이질(Amebic dysentery) 완료. 현재 완료한 객체:  557
# 장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli) 완료. 현재 완료한 객체:  558
# 중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom) 완료. 현재 완료한 객체:  559
# 흑사병(Yersinia Pestis) 완료. 현재 완료한 객체:  560
# 흉부 대동맥류(Thoracic aortic Aneurysm) 완료. 현재 완료한 객체:  561
# 자가면역 질환(autoimmune diseasse) 완료. 현재 완료한 객체:  562
# 강박 장애(Obsessive-Compulsive Disorder) 완료. 현재 완료한 객체:  563
# 폐색성 혈전 혈관염 (Thromboangiitis obliterans) 완료. 현재 완료한 객체:  564
# 망막 열공(retina tear) 완료. 현재 완료한 객체:  565
# 불안정형 협심증(Unstable angina) 완료. 현재 완료한 객체:  566
# 안암(eye cancer) 완료. 현재 완료한 객체:  567
# 심실 세동(Ventricular fibrillation) 완료. 현재 완료한 객체:  568
# 충수암(appendiceal carcinoma) 완료. 현재 완료한 객체:  569
# 심실 빈맥(Ventricular tachycardia) 완료. 현재 완료한 객체:  570
# 대동맥판막 기능부전(Aortic (valve) insufficiency) 완료. 현재 완료한 객체:  571
# 대동맥판막 협착(Aortic (valve) stenosis) 완료. 현재 완료한 객체:  572
# 서맥(Bradycardia) 완료. 현재 완료한 객체:  573
# 심내막염(Endocarditis) 완료. 현재 완료한 객체:  574
# 저혈압(Hypotension) 완료. 현재 완료한 객체:  575
# 림프부종(Lymphedema) 완료. 현재 완료한 객체:  576
# 통풍성 관절염(gouty arthritis) 완료. 현재 완료한 객체:  577
# 안와 골절(orbital fracture) 완료. 현재 완료한 객체:  578
# 근근막 통증 증후군(myofascial pain syndrome) 완료. 현재 완료한 객체:  579
# 색약(color amblyopia) 완료. 현재 완료한 객체:  580
# 팔죽지 골절(Humerus fracture) 완료. 현재 완료한 객체:  581
# 구순염(Cheilitis) 완료. 현재 완료한 객체:  582
# 가습기 살균제 연관 폐질환(Humidifier disinfectant-associated lung injury) 완료. 현재 완료한 객체:  583
# 넬슨 증후군(Nelson's syndrome) 완료. 현재 완료한 객체:  584
# 모공성 각화증(Keratosis pilaris) 완료. 현재 완료한 객체:  585
# 옻 중독(Poison ivy dermatitis) 완료. 현재 완료한 객체:  586
# 레이노병(Raynaud'S Phenomenon) 완료. 현재 완료한 객체:  587
# 승모판 기능부전(Mitral (valve) insufficiency) 완료. 현재 완료한 객체:  588
# 습관성 유산(Habitual miscarriage) 완료. 현재 완료한 객체:  589
# 승모판 협착(Mitral (valve) stenosis) 완료. 현재 완료한 객체:  590
# 구순포진(Herpes labialis) 완료. 현재 완료한 객체:  591
# 뎅기열(Dengue fever) 완료. 현재 완료한 객체:  592
# 뇌염(Encephalitis) 완료. 현재 완료한 객체:  593
# 가와사키병(Kawasaki Disease) 완료. 현재 완료한 객체:  594
# 일본 뇌염(Japanese encephalitis) 완료. 현재 완료한 객체:  595
# 심계항진(Palpitations) 완료. 현재 완료한 객체:  596
# 심낭 삼출 (Pericardial effusion) 완료. 현재 완료한 객체:  597
# 장티푸스(typhoid fever) 완료. 현재 완료한 객체:  598
# 심낭염(Pericarditis) 완료. 현재 완료한 객체:  599
# 수부 습진(Hand Eczema) 완료. 현재 완료한 객체:  600
# 폐성 고혈압(Pulmonary hypertension) 완료. 현재 완료한 객체:  601
# 난청(hearing loss) 완료. 현재 완료한 객체:  602
# 동기능 부전 증후군(Sick sinus syndrome) 완료. 현재 완료한 객체:  603
# 경동맥 협착증(Carotid artery stenosis) 완료. 현재 완료한 객체:  604
# 심장신경성 실신(Neurocardiogenic syncope) 완료. 현재 완료한 객체:  605
# 발작성 상심실성 빈맥(Paroxysmal Supraventricular Tachycardia) 완료. 현재 완료한 객체:  606
# 측두동맥염(Temporal arteritis) 완료. 현재 완료한 객체:  607
# WPW 증후군(Wolff-Parkinson-White syndrome) 완료. 현재 완료한 객체:  608
# 급성 중이염(Acute otitis media) 완료. 현재 완료한 객체:  609
# 협심증(Angina pectoris) 완료. 현재 완료한 객체:  610
# 국소 다한증(Localized hyperhidrosis) 완료. 현재 완료한 객체:  611
# 규폐증(Silicosis) 완료. 현재 완료한 객체:  612
# 귀두포피염(Balanoposthitis) 완료. 현재 완료한 객체:  613
# 늑막염(Pleurisy) 완료. 현재 완료한 객체:  614
# 잠복고환증(Cryptorchidism) 완료. 현재 완료한 객체:  615
# 부고환염(Epididymitis) 완료. 현재 완료한 객체:  616
# 특발성 폐섬유화증(Idiopathic pulmonary fibrosis) 완료. 현재 완료한 객체:  617
# 임균성 요도염(Gonococcal urethritis) 완료. 현재 완료한 객체:  618
# 혈정액증(Hematospermia) 완료. 현재 완료한 객체:  619
# 카르시노이드 증후군(Carcinoid syndrome) 완료. 현재 완료한 객체:  620
# 신증후성 출혈열(Hemorrhagic fever with renal syndrome) 완료. 현재 완료한 객체:  621
# 결핵(Tuberculosis) 완료. 현재 완료한 객체:  622
# 수신증(Hydronephrosis) 완료. 현재 완료한 객체:  623
# 요도하열(Hypospadias) 완료. 현재 완료한 객체:  624
# 면역글로불린 A 신병증(IgA nephropathy) 완료. 현재 완료한 객체:  625
# 농흉(Pyothorax, Empyema) 완료. 현재 완료한 객체:  626
# 남성 불임(Male infertility) 완료. 현재 완료한 객체:  627
# 음낭내 부속기 염전(Intrascrotal appendage, torsion) 완료. 현재 완료한 객체:  628
# 비임균성 요도염(Nongonococcal urethritis) 완료. 현재 완료한 객체:  629
# 포경(Phimosis) 완료. 현재 완료한 객체:  630
# 고환염(Orchitis) 완료. 현재 완료한 객체:  631
# 감돈포경(Paraphimosis) 완료. 현재 완료한 객체:  632
# 조루증(Premature ejaculation) 완료. 현재 완료한 객체:  633
# 음경 발기지속증(Priapism) 완료. 현재 완료한 객체:  634
# 신장 이형성증(Renal dysplasia) 완료. 현재 완료한 객체:  635
# 소변 정체(Retention of urine) 완료. 현재 완료한 객체:  636
# 고환의 염전(Torsion of testis) 완료. 현재 완료한 객체:  637
# 신우요관 폐색(UPJ obstruction) 완료. 현재 완료한 객체:  638
# 요실금(Urinary incontinence) 완료. 현재 완료한 객체:  639
# 요로결석(Urolithiasis) 완료. 현재 완료한 객체:  640
# 방광요관 역류(Vesicoureteral reflux) 완료. 현재 완료한 객체:  641
# 만성 전립선염(Chronic prostatitis) 완료. 현재 완료한 객체:  642
# 방광의 신경근육 기능 장애(Neuromuscular dysfunction of bladder) 완료. 현재 완료한 객체:  643
# 요관 협착(Ureteral stricture) 완료. 현재 완료한 객체:  644
# 방광소장 누공(Vesicointestinal fistula) 완료. 현재 완료한 객체:  645
# 방광질 누공(Vesicovaginal fistula) 완료. 현재 완료한 객체:  646
# 무증상 세균뇨(Asymptomatic bacteriuria) 완료. 현재 완료한 객체:  647
# 임질(Gonorrhea) 완료. 현재 완료한 객체:  648
# 미세변화 신증후군(Minimal change nephrotic syndrome) 완료. 현재 완료한 객체:  649
# 정자부족증(Oligospermia) 완료. 현재 완료한 객체:  650
# 음경만곡증(Peyronie’s disease) 완료. 현재 완료한 객체:  651
# 성병(Sexually transmitted disease) 완료. 현재 완료한 객체:  652
# 요독증(Uremia) 완료. 현재 완료한 객체:  653
# 결막염(Conjunctivitis) 완료. 현재 완료한 객체:  654
# 각막 궤양(Corneal ulcer) 완료. 현재 완료한 객체:  655
# 출혈성 결막염(Hemorrhagic conjunctivitis) 완료. 현재 완료한 객체:  656
# 안검하수(Ptosis of eyelid) 완료. 현재 완료한 객체:  657
# 맥립종(Stye) 완료. 현재 완료한 객체:  658
# 난시(Astigmatism) 완료. 현재 완료한 객체:  659
# 근시(Myopia) 완료. 현재 완료한 객체:  660
# 노안(Presbyopia) 완료. 현재 완료한 객체:  661
# 망막 출혈(Retinal hemorrhage) 완료. 현재 완료한 객체:  662
# 맥락막 흑색종(Choroidal melanoma) 완료. 현재 완료한 객체:  663
# 복시(Diplopia) 완료. 현재 완료한 객체:  664
# 비문증(Floaters) 완료. 현재 완료한 객체:  665
# 진균성 각막 궤양(Fungal corneal ulcers) 완료. 현재 완료한 객체:  666
# 홍채염(Iritis) 완료. 현재 완료한 객체:  667
# 원추각막(Keratoconus) 완료. 현재 완료한 객체:  668
# 수정체 탈구(Lens luxation) 완료. 현재 완료한 객체:  669
# 야맹증(Night blindness) 완료. 현재 완료한 객체:  670
# 가성근시(Pseudomyopia) 완료. 현재 완료한 객체:  671
# 익상편(Pterygium) 완료. 현재 완료한 객체:  672
# 망막색소변성증(Retinitis Pigmentosa) 완료. 현재 완료한 객체:  673
# 설맹(Snow blindness) 완료. 현재 완료한 객체:  674
# 유방 농양(Abscess of breast) 완료. 현재 완료한 객체:  675
# 유방의 엽상 종양(Benign phyllodes tumor of breast) 완료. 현재 완료한 객체:  676
# 유방 종양(Breast mass) 완료. 현재 완료한 객체:  677
# 유방의 섬유선종(Fibroadenoma of breast) 완료. 현재 완료한 객체:  678
# 여성형 유방(Gynecomastia) 완료. 현재 완료한 객체:  679
# 고지혈증(Hyperlipidemia) 완료. 현재 완료한 객체:  680
# 유방의 유선관내 유두종(Intraductal papilloma of breast) 완료. 현재 완료한 객체:  681
# 함몰 유두(Inverted nipple) 완료. 현재 완료한 객체:  682
# 유선염(Mastitis) 완료. 현재 완료한 객체:  683
# 점액수종 혼수(Myxoedema coma) 완료. 현재 완료한 객체:  684
# 갈색세포종(Pheochromocytoma) 완료. 현재 완료한 객체:  685
# 폐부종(Pulmonary edema) 완료. 현재 완료한 객체:  686
# 갑상설관 낭종(Thyroglossal duct cyst) 완료. 현재 완료한 객체:  687
# 당뇨병성 말초신경병증(Diabetic polyneuropathy) 완료. 현재 완료한 객체:  688
# 뇌하수체 기능항진(Hyperfunction of pituitary gland) 완료. 현재 완료한 객체:  689
# 부갑상선기능항진증(Hyperparathyroidism) 완료. 현재 완료한 객체:  690
# 유관 확장증(Mammary duct ectasia) 완료. 현재 완료한 객체:  691
# 흉선암(Thymus Cancer) 완료. 현재 완료한 객체:  692
# 유방의 미세석회화(Microcalcification of breast) 완료. 현재 완료한 객체:  693
# 갑상선염(Thyroiditis) 완료. 현재 완료한 객체:  694
# 말단비대증(Acromegaly) 완료. 현재 완료한 객체:  695
# 항인지질 항체 증후군(Antiphospholipid antibody syndrome) 완료. 현재 완료한 객체:  696
# 갑상선 여포암(Follicular thyroid cancer) 완료. 현재 완료한 객체:  697
# 갑상선 기능 항진증(Hyperthyroidism) 완료. 현재 완료한 객체:  698
# 갑상선 수질암(Medullary thyroid cancer) 완료. 현재 완료한 객체:  699
# 포르피린증(Porphyria) 완료. 현재 완료한 객체:  700
# 갑상선 미분화암(Undifferentiated thyroid cancer) 완료. 현재 완료한 객체:  701
# 급성 류마티스성 열(Acute Rheumatic fever) 완료. 현재 완료한 객체:  702
# 보툴리즘 중독(Botulism) 완료. 현재 완료한 객체:  703
# 무른 궤양(Chancroid) 완료. 현재 완료한 객체:  704
# 혼수(Coma) 완료. 현재 완료한 객체:  705
# 압궤 손상(Crushing injury) 완료. 현재 완료한 객체:  706
# 단독(Erysipelas) 완료. 현재 완료한 객체:  707
# 돌발성 발진(Exanthem subitum) 완료. 현재 완료한 객체:  708
# 소화관의 이물(Foreign body in alimentary tract) 완료. 현재 완료한 객체:  709
# 식도의 이물(Foreign body in esophagus) 완료. 현재 완료한 객체:  710
# 가스 괴저(Gas gangrene) 완료. 현재 완료한 객체:  711
# 고칼슘혈증(Hypercalcemia) 완료. 현재 완료한 객체:  712
# 고칼륨혈증(Hyperkalemia) 완료. 현재 완료한 객체:  713
# 고마그네슘혈증(Hypermagnesemia) 완료. 현재 완료한 객체:  714
# 고나트륨혈증(Hypernatremia) 완료. 현재 완료한 객체:  715
# 저칼슘혈증(Hypocalcemia) 완료. 현재 완료한 객체:  716
# 저칼륨혈증(Hypokalemia) 완료. 현재 완료한 객체:  717
# 저마그네슘혈증(Hypomagnesemia) 완료. 현재 완료한 객체:  718
# 저나트륨혈증(Hyponatremia) 완료. 현재 완료한 객체:  719
# 저체온증(Hypothermia) 완료. 현재 완료한 객체:  720
# 대사성 알칼리증(Metabolic Alkalosis) 완료. 현재 완료한 객체:  721
# 호흡성 산증(Respiratory Acidosis) 완료. 현재 완료한 객체:  722
# 호흡성 알칼리증(Respiratory Alkalosis) 완료. 현재 완료한 객체:  723
# 횡문근융해증(Rhabdomyolysis) 완료. 현재 완료한 객체:  724
# 익수(Submersion) 완료. 현재 완료한 객체:  725
# 독성 쇼크 증후군(Toxic shock syndrome) 완료. 현재 완료한 객체:  726
# 외상에 의한 척수 손상(Traumatic Spinal cord injury) 완료. 현재 완료한 객체:  727
# 장염전(Volvulus) 완료. 현재 완료한 객체:  728
# 대사성 산증(Metabolic Acidosis) 완료. 현재 완료한 객체:  729
# 패혈증(Sepsis) 완료. 현재 완료한 객체:  730
# 이물질에 의한 기도막힘(Airway obstruction) 완료. 현재 완료한 객체:  731
# 화상(Burn) 완료. 현재 완료한 객체:  732
# 벌에 쏘였을 때(Bee bite) 완료. 현재 완료한 객체:  733
# 일산화탄소 중독(Carbon monoxide-poisoning) 완료. 현재 완료한 객체:  734
# 식중독(Foodborne illness) 완료. 현재 완료한 객체:  735
# 열사병(Heat stroke) 완료. 현재 완료한 객체:  736
# 악성 고열증(Malignant hyperthermia) 완료. 현재 완료한 객체:  737
# 고산병(Mountain sickness) 완료. 현재 완료한 객체:  738
# 열 피로(heat exhaustion) 완료. 현재 완료한 객체:  739
# 18번 염색체 단완결실 증후군(18p monosomy) 완료. 현재 완료한 객체:  740
# 18번 염색체 장완결실 증후군 (18q monosomy) 완료. 현재 완료한 객체:  741
# 연골무형성증(Achondroplasia) 완료. 현재 완료한 객체:  742
# 부신백질이영양증(Adrenoleukodystrophy) 완료. 현재 완료한 객체:  743
# 안드로겐 불감성 증후군 (Androgen insensitivity syndrome(AIS)) 완료. 현재 완료한 객체:  744
# 엔젤만 증후군(Angelman syndrome) 완료. 현재 완료한 객체:  745
# 에이퍼트 증후군 (Apert syndrome) 완료. 현재 완료한 객체:  746
# ARC 증후군(Arthrogryposis, Renal dysfunction, Cholestasis, ARC syndrome) 완료. 현재 완료한 객체:  747
# 모세혈관 확장성 운동실조 증후군 (Ataxia-telangiectasia syndrome) 완료. 현재 완료한 객체:  748
# 베커형 근이영양증(Becker muscular dystrophy) 완료. 현재 완료한 객체:  749
# 베크위트-위드만 증후군(Beckwith-Wiedemann syndrome) 완료. 현재 완료한 객체:  750
# Best 난황형 황반부 이영양증 (Best vitelliform macular dystrophy) 완료. 현재 완료한 객체:  751
# 카르니틴 팔미토일 전환효소 결핍증 2형(Carnitine Palmitoyltransferase II Deficiency) 완료. 현재 완료한 객체:  752
# 22번 염색체 장완 미세결실 증후군(CATCH22) 완료. 현재 완료한 객체:  753
# 피질하 경색과 백질뇌증을 동반하는 상염색체 우성 뇌동맥질환(Cerebral Autosomal Dominant Arteriopathy with Subcortical Infarcts and Leukoencephalopathy) 완료. 현재 완료한 객체:  754
# 사이트린 결핍(Citrin deficiency) 완료. 현재 완료한 객체:  755
# 시트룰닌혈증(Citrullinemia) 완료. 현재 완료한 객체:  756
# 선천성 부신과다 형성증(Congenital adrenal hyperplasia) 완료. 현재 완료한 객체:  757
# 선천성 갑상선 기능 저하증(Congenital hypothyroidism) 완료. 현재 완료한 객체:  758
# 코넬리아드랑게 증후군 (Cornelia de Lange syndrome) 완료. 현재 완료한 객체:  759
# 묘성 증후군(Cri du Chat syndrome) 완료. 현재 완료한 객체:  760
# 크루존 증후군(Crouzon syndrome) 완료. 현재 완료한 객체:  761
# Haw River 증후군(Dentatorubro-Pallidoluysian atrophy(DRPLA)) 완료. 현재 완료한 객체:  762
# 다운 증후군 (Down syndrome) 완료. 현재 완료한 객체:  763
# 듀시엔형 근이영양증 (Duchenne muscular dystrophy) 완료. 현재 완료한 객체:  764
# 에드워드 증후군 (Edwards syndrome) 완료. 현재 완료한 객체:  765
# 엘러스-단로스 증후군 (Ehlers-Danlos syndrome) 완료. 현재 완료한 객체:  766
# 연골외배엽 이형성증 (Ellis-van Creveld syndrome) 완료. 현재 완료한 객체:  767
# 파브리병(Fabry disease) 완료. 현재 완료한 객체:  768
# 판코니범혈구감소증(Fanconi Pancytopenia syndrome) 완료. 현재 완료한 객체:  769
# 유약 X 증후군(Fragile X syndrome) 완료. 현재 완료한 객체:  770
# 프리이드라이히 운동실조증 (Friedreich ataxia) 완료. 현재 완료한 객체:  771
# 갈락토오스혈증(Galactosemia) 완료. 현재 완료한 객체:  772
# 고셔병(Gaucher disease) 완료. 현재 완료한 객체:  773
# 당원축적병(Glycogen storage disease) 완료. 현재 완료한 객체:  774
# 골덴하 증후군(Goldenhar syndrome) 완료. 현재 완료한 객체:  775
# 혈색소침착증(Hemochromatosis) 완료. 현재 완료한 객체:  776
# 가족성 적혈구잠식성 림프조직구증(Hemophagocytic lymphohistiocytosis, Familial) 완료. 현재 완료한 객체:  777
# 혈우병(Hemophilia) 완료. 현재 완료한 객체:  778
# 홀트-오람 증후군 (Holt-Oram syndrome) 완료. 현재 완료한 객체:  779
# 호모시스틴뇨증(Homocystinuria) 완료. 현재 완료한 객체:  780
# 헌터 증후군(Hunter Syndrome) 완료. 현재 완료한 객체:  781
# 헌팅톤 병(Huntington disease) 완료. 현재 완료한 객체:  782
# 헐러 증후군(Hurler syndrome) 완료. 현재 완료한 객체:  783
# 연골형성저하증(Hypochondroplasia) 완료. 현재 완료한 객체:  784
# 저인산증(Hypophosphatasia) 완료. 현재 완료한 객체:  785
# 클라인펠터 증후군 (Klinefelter syndrome) 완료. 현재 완료한 객체:  786
# 클리펠-트라우네이-베버 증후군(Klippel-Trenaunay-Weber syndrome) 완료. 현재 완료한 객체:  787
# Kniest dysplasia (Kniest dysplasia ) 완료. 현재 완료한 객체:  788
# 레버씨 시신경 위축증 (Leber hereditary optic neuropathy(LHON)) 완료. 현재 완료한 객체:  789
# 리 증후군(Leigh syndrome) 완료. 현재 완료한 객체:  790
# 다발성 흑자 증후군(LEOPARD syndrome) 완료. 현재 완료한 객체:  791
# 레쉬-니한 증후군 (Lesch-Nyhan syndrome) 완료. 현재 완료한 객체:  792
# 로우 증후군(Lowe syndrome) 완료. 현재 완료한 객체:  793
# 단풍당밀뇨증(Maple-syrup urine disease) 완료. 현재 완료한 객체:  794
# 마르판 증후군 (Marfan syndrome) 완료. 현재 완료한 객체:  795
# Maroteaux-Lamy 증후군(Maroteaux-Lamy Syndrome) 완료. 현재 완료한 객체:  796
# 중쇄 아실코에이 탈수소효소 결핍증(Medium-Chain Acyl-Coenzyme A Dehydrogenase Deficiency(MCAD deficiency)) 완료. 현재 완료한 객체:  797
# 미토콘드리아성 뇌근육병증(MELAS, lactic acidosis, and stroke-like episodes) 완료. 현재 완료한 객체:  798
# 멘케스병(Menkes disease) 완료. 현재 완료한 객체:  799
# 이염성 백질이영양증 (Metachromatic leukodystrophy) 완료. 현재 완료한 객체:  800
# 메틸말론산증(Methylmalonic acidemia) 완료. 현재 완료한 객체:  801
# Morquio disease (Morquio syndrome ,Mucopolysaccharidosis IV형) 완료. 현재 완료한 객체:  802
# 뮤코다당질축적증(Mucopolysaccharidoses) 완료. 현재 완료한 객체:  803
# MERRF(Myoclonic Epilepsy with Ragged Red Fiber) 증후군(Myoclonic epilepsy associated with ragged red fibers(MERRF)) 완료. 현재 완료한 객체:  804
# 근긴장성 이영양증 (Myotonic dystrophy) 완료. 현재 완료한 객체:  805
# 신경섬유종(Neurofibromatosis) 완료. 현재 완료한 객체:  806
# 니만-피크병(Niemann-Pick disease) 완료. 현재 완료한 객체:  807
# 누난 증후군 (Noonan syndrome) 완료. 현재 완료한 객체:  808
# OTC 결핍증 (Ornithine-transcarbamylase deficiency) 완료. 현재 완료한 객체:  809
# 골형성부전증(Osteogenesis imperfecta) 완료. 현재 완료한 객체:  810
# 파타우 증후군(Patau syndrome) 완료. 현재 완료한 객체:  811
# 파이퍼 증후군 (Pfeiffer syndrome) 완료. 현재 완료한 객체:  812
# 페닐케톤뇨증(Phenylketonuria) 완료. 현재 완료한 객체:  813
# 폼페병(Pompe disease) 완료. 현재 완료한 객체:  814
# 프라더 윌리 증후군 (Prader-Willi syndrome) 완료. 현재 완료한 객체:  815
# 프로피온산증(Propionic acidemia) 완료. 현재 완료한 객체:  816
# 레트 증후군 (Rett syndrome) 완료. 현재 완료한 객체:  817
# 루빈스타인 테이비 증후군 (Rubinstein-Taybi syndrome) 완료. 현재 완료한 객체:  818
# 러셀 실버 증후군 (Russell-Silver syndrome) 완료. 현재 완료한 객체:  819
# Sanfilippo 증후군(Sanfilippo syndrome) 완료. 현재 완료한 객체:  820
# Sly 증후군(Sly Syndrome) 완료. 현재 완료한 객체:  821
# 스미스-마제니스 증후군 (Smith-Magenis syndrome, SMS) 완료. 현재 완료한 객체:  822
# 대뇌성 거인증 (Sotos syndrome) 완료. 현재 완료한 객체:  823
# 척수근육위축(Spinal muscular atrophy) 완료. 현재 완료한 객체:  824
# 척수구근 근위축증 (Spinobulbar muscular atrophy) 완료. 현재 완료한 객체:  825
# 척수소뇌성 운동실조증 (Spinocerebellar ataxia, SCA) 완료. 현재 완료한 객체:  826
# 스티클러 증후군(Stickler syndrome) 완료. 현재 완료한 객체:  827
# 테이-삭스병 (Tay-Sachs disease) 완료. 현재 완료한 객체:  828
# 트리처 콜린스 증후군 (Treacher-Collins syndrome) 완료. 현재 완료한 객체:  829
# 결절성 경화증 (Tuberous sclerosis) 완료. 현재 완료한 객체:  830
# 터너 증후군 (Turner syndrome) 완료. 현재 완료한 객체:  831
# 본히펠린다우 증후군 (Von Hippel-Lindau syndrome) 완료. 현재 완료한 객체:  832
# 바르덴부르크 증후군(Waardenburg syndrome) 완료. 현재 완료한 객체:  833
# 윌리암스 증후군 (Williams syndrome) 완료. 현재 완료한 객체:  834
# 윌슨병(Willson disease) 완료. 현재 완료한 객체:  835
# 윌름즈 종양(Wilms Tumor) 완료. 현재 완료한 객체:  836
# 4번 염색체 단완결실 증후군(Wolf-Hirschhorn syndrome) 완료. 현재 완료한 객체:  837
# XXX 증후군(XXX syndrome) 완료. 현재 완료한 객체:  838
# XYY 증후군(XYY syndrome) 완료. 현재 완료한 객체:  839
# 이석증(Benign paroxysmal vertigo) 완료. 현재 완료한 객체:  840
# 미로염(Labyrinthitis) 완료. 현재 완료한 객체:  841
# 루드비히 안자이나 (Ludwig's angina) 완료. 현재 완료한 객체:  842
# 외이도염(Otitis externa) 완료. 현재 완료한 객체:  843
# 외상에 의한 고막 천공(Traumatic rupture of ear drum [Traumatic tympanic membrane perforation]) 완료. 현재 완료한 객체:  844
# 현훈(Vertigo) 완료. 현재 완료한 객체:  845
# 전정신경염(Vestibular neuronitis) 완료. 현재 완료한 객체:  846
# 진주종(Cholesteatoma) 완료. 현재 완료한 객체:  847
# 만성 비염(Chronic rhinitis) 완료. 현재 완료한 객체:  848
# 메니에르병(Meniere's disease) 완료. 현재 완료한 객체:  849
# 비용종(Nasal polyp) 완료. 현재 완료한 객체:  850
# 이루증(Otorrhea) 완료. 현재 완료한 객체:  851
# 이명(Tinnitus) 완료. 현재 완료한 객체:  852
# 편도선염(Tonsillitis) 완료. 현재 완료한 객체:  853
# 인후두염(Laryngopharyngitis) 완료. 현재 완료한 객체:  854
# 고막염(Myringitis) 완료. 현재 완료한 객체:  855
# 이하선염(Parotitis) 완료. 현재 완료한 객체:  856
# 노인성 난청(Presbycusis) 완료. 현재 완료한 객체:  857
# 타석증(Sialolithiasis) 완료. 현재 완료한 객체:  858
# 이식편대숙주질환(Graft-versus-host reaction or disease(GVHD)) 완료. 현재 완료한 객체:  859
# 면역혈소판감소증(Immune thrombocytopenia) 완료. 현재 완료한 객체:  860
# 감염성 단핵구증(Infectious mononucleosis) 완료. 현재 완료한 객체:  861
# 원발성 중추신경계 림프종(Primary CNS lymphoma) 완료. 현재 완료한 객체:  862
# 베게너 육아종증(Wegener granulomatosis) 완료. 현재 완료한 객체:  863
# 악액질(Cachexia) 완료. 현재 완료한 객체:  864
# 조혈모세포 이식(Stem cell transplantation) 완료. 현재 완료한 객체:  865
# 유잉육종(Ewing sarcoma) 완료. 현재 완료한 객체:  866
# 과오종(Hamartoma) 완료. 현재 완료한 객체:  867
# 랑거한스세포 조직구증식증(Langerhans cell histiocytosis) 완료. 현재 완료한 객체:  868
# 폰빌레브란트병(Von Willebrand disease) 완료. 현재 완료한 객체:  869
# 턱관절 탈구(Luxation of the mandible) 완료. 현재 완료한 객체:  870
# 설통(Glossodynia) 완료. 현재 완료한 객체:  871
# 치조골염(Alveolar ostitis) 완료. 현재 완료한 객체:  872
# 치아 우식증[충치](Dental Caries) 완료. 현재 완료한 객체:  873
# 치은염(Gingivitis) 완료. 현재 완료한 객체:  874
# 치주 농양(Periodontal abscess) 완료. 현재 완료한 객체:  875
# 탈모(Alopecia) 완료. 현재 완료한 객체:  876
# 기저세포 암종(Basal cell carcinoma) 완료. 현재 완료한 객체:  877
# 기저귀 피부염(Diaper (napkin) dermatitis) 완료. 현재 완료한 객체:  878
# 천포창(Pemphigus) 완료. 현재 완료한 객체:  879
# 옴(Scabies) 완료. 현재 완료한 객체:  880
# 피부건조증(Xerosis cutis) 완료. 현재 완료한 객체:  881
# 티눈 및 굳은 살(Corns and callosities) 완료. 현재 완료한 객체:  882
# 피부염(Dermatitis) 완료. 현재 완료한 객체:  883
# 상피내 신생물(IN SITU NEOPLASMS) 완료. 현재 완료한 객체:  884
# 내향성 손발톱(Ingrowing nails) 완료. 현재 완료한 객체:  885
# 악성 흑색종(Malignant melanoma) 완료. 현재 완료한 객체:  886
# 땀띠(Miliaria) 완료. 현재 완료한 객체:  887
# 소양증(Pruritus) 완료. 현재 완료한 객체:  888
# 광선 각화증(Actinic Keratosis) 완료. 현재 완료한 객체:  889
# 무모증(Atrichia pubis) 완료. 현재 완료한 객체:  890
# 비듬(Dandruff) 완료. 현재 완료한 객체:  891
# 습진(Eczema) 완료. 현재 완료한 객체:  892
# 다모증(Excessive hair growth) 완료. 현재 완료한 객체:  893
# 주근깨(Freckle,Ephelis) 완료. 현재 완료한 객체:  894
# 안면 홍조증(Hot flush) 완료. 현재 완료한 객체:  895
# 어린선(Ichthyosis) 완료. 현재 완료한 객체:  896
# 켈로이드(Keloid) 완료. 현재 완료한 객체:  897
# 만성 단순 태선(Lichen simplex chronicus) 완료. 현재 완료한 객체:  898
# 비립종(Milium) 완료. 현재 완료한 객체:  899
# 오타 모반(Ota like Melanosis) 완료. 현재 완료한 객체:  900
# 딸기코(Rosacea) 완료. 현재 완료한 객체:  901
# 쥐젖(Soft fibroma) 완료. 현재 완료한 객체:  902
# 안검황색종(Xanthelasma) 완료. 현재 완료한 객체:  903
# 폐의 농양(Abscess of lung) 완료. 현재 완료한 객체:  904
# 흡인성 폐렴(Aspiration pneumonia) 완료. 현재 완료한 객체:  905
# 폐렴간균에 의한 폐렴 (Klebsiella pneumoniae infection) 완료. 현재 완료한 객체:  906
# 아스페르길루스증(Aspergillosis) 완료. 현재 완료한 객체:  907
# 만성 기관지염(Chronic bronchitis) 완료. 현재 완료한 객체:  908

# %%
# http://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=
# 확인용 테스트    질환 정보 0-907  -> 총 908개 
i = 900 
print("질환명: ", diseases[i].name)
print("관련증상: ")
for symptom in diseases[i].related_symptoms:
    print(symptom)
print("관련질환: ")
for dis in diseases[i].related_diseases:
    print(dis)
print("관련 진료과: ")
for medDep in diseases[i].medDeps:
    print(medDep)
print("동의어: ", diseases[i].synonym)
print()
print("관련 설명: ")
for k, v in diseases[i].descrips.items():
    print(k)
    print(v)
print()
print("건강 이야기: ")
for k, v in diseases[i].healthStory.items():
    print(k)
    print(v)

# %%
txt= ""
for disease in diseases:
    txt = txt + "================================= \n"
    txt = txt + "질환명: " + disease.name + "\n"
    if len(disease.related_symptoms) >= 1:
        txt = txt + "관련증상: " + "\n"
        for symptom in disease.related_symptoms:
            txt = txt + symptom + "\n"
    if len(disease.related_diseases) >= 1:
        txt = txt + "관련질환: " + "\n"
        for dis in disease.related_diseases:
            txt = txt + dis + "\n"
    if len(disease.medDeps) >= 1:
        txt = txt + "관련진료과: " + "\n"
        for medDep in disease.medDeps:
            txt = txt + medDep + "\n"
    if len(disease.synonym) >= 1:
        txt = txt + "동의어: " + disease.synonym + "\n"
    if len(disease.descrips) >= 1:
        txt = txt + "관련 설명: " + "\n"
        for k, v in disease.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    if len(disease.healthStory) >= 1:
        txt = txt + "건강 이야기: " + "\n"
        for k, v in disease.healthStory.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    txt = txt + "================================= \n"

with open("./output/whole/diseases.txt", "w") as text_file:
    text_file.write(txt)

# %%
txt= ""
for disease in diseases:
    txt = txt + "질환명: " + disease.name + "\n"
    if len(disease.descrips) >= 1:
        txt = txt + "관련 설명: " + "\n"
        for k, v in disease.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    if len(disease.healthStory) >= 1:
        txt = txt + "건강 이야기: " + "\n"
        for k, v in disease.healthStory.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"

with open("./output/whole/diseases_description.txt", "w") as text_file:
    text_file.write(txt)

# %%
for disease in diseases:
    if (disease.name.find('/') != -1):
        disease.name = disease.name.replace('/','')

# %%
# 항목별 텍스트
for disease in diseases:
    txt= ""
    txt = txt + "질환명: " + disease.name + "\n"
    if len(disease.descrips) >= 1:
        txt = txt + "관련 설명: " + "\n"
        for k, v in disease.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    if len(disease.healthStory) >= 1:
        txt = txt + "건강 이야기: " + "\n"
        for k, v in disease.healthStory.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    with open("./output/diseases_"+ disease.name +".txt", "w") as text_file:
        text_file.write(txt)

# %% [markdown]
# # 검사/시술/수술 정보 추출

# %%
class Intervention:
    name="" # 검사 제목
    availableTabs=defaultdict() # 현재페이지에 이용가능한 탭과 그 링크
    related_parts=[] #관련 신체 부위
    related_areas=[] # 관련 질환 분야
    related_interventions=[] #관련검사
    medDeps=[] # 관련진료과
    descrips=defaultdict() # 검사 설명
    related_diseases=[] # 관련질환
    related_bodies=[] # 관련 인체

# %%
interventionList = []
st = "http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?managementId="

for i in range(546):
        stnew = st + str(i+1)
        interventionList.append(stnew)

# %%
# http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?managementId=1
# http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?managementId=546

#http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?
#managementId=20    검사 아이디
#&tabIndex=3        탭 번호 0: 설명 / 1: 관련 질환 / 3: 관련 인체

# 검사/시술/수술 정보 총 546개  managementId= 1 - 546

def intervention_extract(interventionList):
    interventions = []
    for address in interventionList: # http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?managementId=
        browser.get(address)
        if browser.find_elements_by_class_name("contTitle")[0].text == "()":
            continue
        
        intervention = Intervention()
        tableIndex= ["1", "3"]

        # 신체 이름
        summaryBox = browser.find_elements_by_class_name("contBox")
        title = summaryBox[0].find_elements_by_class_name("contTitle")
        intervention.name = title[0].text
        # 신체 이름 - 끝

        # 부위명/질환명/진료과
        summaries = summaryBox[0].find_elements_by_tag_name("dd")
        
        if len(summaries) >= 1: # 부위
            parts = summaries[0].find_elements_by_tag_name("a")
            prts = []
            for part in parts:
                prts.append(part.text)
            intervention.related_parts = prts
            
            if len(summaries) >= 2: # 질환
                diseases = summaries[1].find_elements_by_tag_name("a")
                diss = []
                for disease in diseases:
                    diss.append(disease.text)
                intervention.related_areas = diss
                
                if len(summaries) == 3: # 검사
                    intervenes = summaries[2].find_elements_by_tag_name("a")
                    intvs = []
                    for intervene in intervenes:
                        intvs.append(intervene.text)
                    intervention.related_interventions = intvs

                    if len(summaries) == 4: # 진료과
                        medDeps = summaries[3].find_elements_by_tag_name("a")
                        mdps = []
                        for medDep in medDeps:
                            mdps.append(medDep.text)
                        intervention.medDeps = mdps
        # 부위명/질환명/진료과 - 끝

        
        # 본문 정리 -> 본문 정리는 기본 url로 진행 가능
        ds = {}
        descOuter = browser.find_elements_by_class_name("contDescription")
        titles = descOuter[0].find_elements_by_tag_name("dt")
        contents = descOuter[0].find_elements_by_tag_name("dd")
        if len(titles) == len(contents):
            for titl, conts in zip(titles, contents):
                ds[titl.text] = conts.text
            intervention.descrips = ds
        else:
            print("정의와 설명의 개수가 다름")
        # 본문 정리 - 끝

        
        # 다음 탭으로 이동
        nextUrl = address + "&tabIndex=" + tableIndex[0]
        browser.get(nextUrl)

        # 페이지 길이 파악
        pageOuter = browser.find_elements_by_class_name("numPagingSec")
        if len(pageOuter) >= 1:
            pages = pageOuter[0].find_elements_by_tag_name("a")
            pageLen = int(pages[-1].text) # 전체 페이지 길이
        # 페이지 길이 파악 - 끝

        urlToExplore = [] # 페이지 수에 따라 조사해야 할 url 리스트
        for i in range(pageLen):
                nextUrl = address + "&tabIndex=" + tableIndex[0] + "&pageIndex=" + str(i+1)
                urlToExplore.append(nextUrl)
                
                
        #관련 질병 추출
        dis = []
        for url in urlToExplore:
            browser.get(url)
            diseasesOuter = browser.find_elements_by_class_name("listCont")
            if len(diseasesOuter) >= 1:
                diseases = diseasesOuter[0].find_elements_by_class_name("contTitle")
                for disease in diseases:
                    dis.append(disease.text)
        intervention.related_diseases = dis
        # 관련 질병 추출 -끝
        
        # 다음 탭으로 이동
        nextUrl = address + "&tabIndex=" + tableIndex[1]
        browser.get(nextUrl)

        # 페이지 길이 파악
        pageOuter = browser.find_elements_by_class_name("numPagingSec")
        if len(pageOuter) >= 1:
            pages = pageOuter[0].find_elements_by_tag_name("a")
            pageLen = int(pages[-1].text) # 전체 페이지 길이
        # 페이지 길이 파악 - 끝

        urlToExplore = [] # 페이지 수에 따라 조사해야 할 url 리스트
        for i in range(pageLen):
                nextUrl = address + "&tabIndex=" + tableIndex[1] + "&pageIndex=" + str(i+1)
                urlToExplore.append(nextUrl)
                
        # 관련 신체 부위 추출
        bdy = []
        for url in urlToExplore:
            browser.get(url)
            bodiesOuter = browser.find_elements_by_class_name("listCont")
            if len(bodiesOuter) >= 1:
                bodies = bodiesOuter[0].find_elements_by_class_name("contTitle")
                for body in bodies:
                    bdy.append(body.text)
        intervention.related_interventions = bdy
        #관련 신체 부위 추출 - 끝
        
        interventions.append(intervention)
        print(intervention.name, "완료. 현재 완료한 객체: ", len(interventions))
    return interventions

# %%
interventions = intervention_extract(interventionList)
# Out:
# 경피적 간담도조영술(Percutaneous transhepatic cholangiography) 완료. 현재 완료한 객체:  1
# 혈당 검사(Blood sugar test) 완료. 현재 완료한 객체:  2
# 청력 검사(Audiometry) 완료. 현재 완료한 객체:  3
# 초음파 검사(Echography) 완료. 현재 완료한 객체:  4
# 간 초음파 검사(Liver Ultrasonography) 완료. 현재 완료한 객체:  5
# 혈관조영술(Angiography) 완료. 현재 완료한 객체:  6
# 관절조영술(Arthrography) 완료. 현재 완료한 객체:  7
# 기관지조영술(Broncography) 완료. 현재 완료한 객체:  8
# 담낭조영술(Cholecystography) 완료. 현재 완료한 객체:  9
# 담도조영술(Cholangiography) 완료. 현재 완료한 객체:  10
# 방광요도조영술(Cystourethrography) 완료. 현재 완료한 객체:  11
# 배뇨성 방광요도조영술(Voiding cystourethrography) 완료. 현재 완료한 객체:  12
# 식도조영술(Esophagography) 완료. 현재 완료한 객체:  13
# 십이지장조영술(Duodenography) 완료. 현재 완료한 객체:  14
# 양수조영술(Amniography) 완료. 현재 완료한 객체:  15
# 역행성 신우조영술(Retrograde Pyelography ) 완료. 현재 완료한 객체:  16
# 유방촬영술(Mammography) 완료. 현재 완료한 객체:  17
# 정관정낭조영술(Vesiculography) 완료. 현재 완료한 객체:  18
# 정맥신우조영술(Intravenous Pyelography) 완료. 현재 완료한 객체:  19
# 질조영술(Vaginography ) 완료. 현재 완료한 객체:  20
# 척수조영술(Myelography) 완료. 현재 완료한 객체:  21
# 췌장관조영술(Pancreatography) 완료. 현재 완료한 객체:  22
# 자기공명영상검사(MRI) 완료. 현재 완료한 객체:  23
# 전산화단층촬영(CT) 완료. 현재 완료한 객체:  24
# 복강경 검사(Laparoscopy) 완료. 현재 완료한 객체:  25
# 갑상선 기능 검사(Thyroid Function Test) 완료. 현재 완료한 객체:  26
# 신생아 선별검사(Neonatal Screening Test) 완료. 현재 완료한 객체:  27
# 심전도 검사(Electrocardiography) 완료. 현재 완료한 객체:  28
# 관절경검사(Arthroscopy) 완료. 현재 완료한 객체:  29
# F-18 FDG 양전자 방출 단층 촬영(Positron Emission Tomography, PET) 완료. 현재 완료한 객체:  30
# 결핵 검사(Tuberculosis test) 완료. 현재 완료한 객체:  31
# 뇌척수액 검사(Cerebro-Spinal Fluid Examination) 완료. 현재 완료한 객체:  32
# 근전도 검사(Electromyography) 완료. 현재 완료한 객체:  33
# 유방암 검사(Breast examination) 완료. 현재 완료한 객체:  34
# 간 기능 검사(Liver function test) 완료. 현재 완료한 객체:  35
# 방사선 치료(Radiation therapy) 완료. 현재 완료한 객체:  36
# 자궁경부암 검사(Cervical cancer Screening tests) 완료. 현재 완료한 객체:  37
# 자궁난관조영술(Hysterosalphingography) 완료. 현재 완료한 객체:  38
# 수면다원검사(Polysomnography) 완료. 현재 완료한 객체:  39
# 뇌파 검사(Electroencephalography) 완료. 현재 완료한 객체:  40
# 내시경 검사(Endoscopy) 완료. 현재 완료한 객체:  41
# 수면 내시경 검사(Conscious Sedation Endoscopy) 완료. 현재 완료한 객체:  42
# 위 내시경검사(Esophagogastroduodenoscopy) 완료. 현재 완료한 객체:  43
# 대장 내시경 검사(Colonoscopy) 완료. 현재 완료한 객체:  44
# 내시경 역행 췌담관 조영술(Endoscopic Retrograde Cholangio Pancreatography) 완료. 현재 완료한 객체:  45
# 빈혈 검사(Anemia Work-up) 완료. 현재 완료한 객체:  46
# 시력 검사(Assessment of Visual acuity) 완료. 현재 완료한 객체:  47
# 골수 검사(Bone Marrow Examination) 완료. 현재 완료한 객체:  48
# 심리 검사(Psychological testing ) 완료. 현재 완료한 객체:  49
# 간담도 스캔(Hepatobiliary Scintigraphy) 완료. 현재 완료한 객체:  50
# 골밀도 검사(Bone Densitometry) 완료. 현재 완료한 객체:  51
# 기형아 검사(Congenital anomaly test) 완료. 현재 완료한 객체:  52
# 뇌조조영술(Cisternography) 완료. 현재 완료한 객체:  53
# 림프신티그래피(Lymphoscintigraphy) 완료. 현재 완료한 객체:  54
# 섬광조영술(Scintigraphy) 완료. 현재 완료한 객체:  55
# 성병 검사(Sexually Transmitted Diseases Testing) 완료. 현재 완료한 객체:  56
# 산전 검사(Prenatal tests) 완료. 현재 완료한 객체:  57
# 양수 검사(Amniocentesis) 완료. 현재 완료한 객체:  58
# 에이즈 검사(Tests for Acquired Immune Deficiency Syndrome) 완료. 현재 완료한 객체:  59
# 임신성 당뇨검사(Gestational diabetes screening and diagnostic test) 완료. 현재 완료한 객체:  60
# 인공수정(Intrauterine insemination) 완료. 현재 완료한 객체:  61
# 임신 진단 검사(Pregnancy test) 완료. 현재 완료한 객체:  62
# 투석(Dialysis) 완료. 현재 완료한 객체:  63
# C형 간염 항체 선별검사(Hepatitis C Virus antibody screening) 완료. 현재 완료한 객체:  64
# B형 간염 바이러스 유전자 정량검사(Hepatitis B virus deoxyribonucleic acid quantitati) 완료. 현재 완료한 객체:  65
# B형 간염 바이러스 약제 내성 검사(Hepatitis B Virus drug resistance) 완료. 현재 완료한 객체:  66
# B형 간염 표면 항체(Hepatitis B surface antibody) 완료. 현재 완료한 객체:  67
# B형 간염 표면 항원(Hepatitis B surface antigen) 완료. 현재 완료한 객체:  68
# ABO 혈액형 검사(ABO typing) 완료. 현재 완료한 객체:  69
# Rh 혈액형 검사(Rh typing) 완료. 현재 완료한 객체:  70
# C 반응성 단백 시험(C-reactive protein) 완료. 현재 완료한 객체:  71
# 소디움 (Sodium) 완료. 현재 완료한 객체:  72
# 포타슘(Potassium) 완료. 현재 완료한 객체:  73
# 마그네슘(Magnesium) 완료. 현재 완료한 객체:  74
# 칼슘(Calcium) 완료. 현재 완료한 객체:  75
# 피브카 2 정량검사(Proteins Induced by Vitamin K Absence or Antagonis) 완료. 현재 완료한 객체:  76
# 신경 특이 에놀라제(Neuron Specific Enolase) 완료. 현재 완료한 객체:  77
# 리파아제(Lipase) 완료. 현재 완료한 객체:  78
# 아밀라제(Amylase) 완료. 현재 완료한 객체:  79
# 콜레스테롤(Cholesterol) 완료. 현재 완료한 객체:  80
# 중성지방(Triglyceride) 완료. 현재 완료한 객체:  81
# 저밀도 콜레스테롤(Low density lipoprotein cholesterol) 완료. 현재 완료한 객체:  82
# 고밀도 콜레스테롤(High density lipoprotein cholesterol) 완료. 현재 완료한 객체:  83
# 산도(pH) 완료. 현재 완료한 객체:  84
# 요당(Urine glucose) 완료. 현재 완료한 객체:  85
# 단백뇨(Proteinuria) 완료. 현재 완료한 객체:  86
# 요 백혈구(Pyuria) 완료. 현재 완료한 객체:  87
# 요 적혈구(Hematuria) 완료. 현재 완료한 객체:  88
# 요 잠혈(Occult hematuria) 완료. 현재 완료한 객체:  89
# 소변 알부민 크레아티닌 비율(Albumin Cr ratio, Urine) 완료. 현재 완료한 객체:  90
# 미세알부민뇨(Microalbuminuria) 완료. 현재 완료한 객체:  91
# 요산(Uric acid) 완료. 현재 완료한 객체:  92
# FK506 치료적 약물농도 감시(FK506 therapeutic drug monitoring) 완료. 현재 완료한 객체:  93
# 리튬 치료적 약물농도 감시(Lithium therapeutic drug monitoring) 완료. 현재 완료한 객체:  94
# 사이클로스포린 치료적 약물농도 감시(cyclosporine therapeutic drug monitoring) 완료. 현재 완료한 객체:  95
# 발프로산 치료적 약물농도 감시(Valproic acid therapeutic drug monitoring) 완료. 현재 완료한 객체:  96
# 마이코페놀산 치료적 약물농도 감시(Mycophenolic acid therapeutic drug monitoring) 완료. 현재 완료한 객체:  97
# 크레아틴키나제(Creatine Kinase) 완료. 현재 완료한 객체:  98
# 심장형 크레아틴키나제(Creatine Kinase MB Fraction) 완료. 현재 완료한 객체:  99
# 트로포닌아이(Troponin I) 완료. 현재 완료한 객체:  100
# 혈액요소질소(Blood Urea Nitrogen) 완료. 현재 완료한 객체:  101
# 소변 단백질/크레아티닌 비율(Protein/Cr ratio, Urine) 완료. 현재 완료한 객체:  102
# 크레아티닌(Creatinine) 완료. 현재 완료한 객체:  103
# 당화혈색소(HbA1c) 완료. 현재 완료한 객체:  104
# 알부민(Albumin) 완료. 현재 완료한 객체:  105
# 알라닌아미노전달효소(ALanine Transaminase) 완료. 현재 완료한 객체:  106
# 아스파테이트아미노전달효소(ASpartate Transaminase) 완료. 현재 완료한 객체:  107
# 단백질(Protein) 완료. 현재 완료한 객체:  108
# 감마지티(r-glutamyltransferase) 완료. 현재 완료한 객체:  109
# 직접 빌리루빈(Bilirubin, direct) 완료. 현재 완료한 객체:  110
# 총 빌리루빈(Total bilirubin) 완료. 현재 완료한 객체:  111
# 호산구(Eosinophil) 완료. 현재 완료한 객체:  112
# 혈소판(Platelet) 완료. 현재 완료한 객체:  113
# 백혈구(white blood cell) 완료. 현재 완료한 객체:  114
# 중성구(Neutrophil) 완료. 현재 완료한 객체:  115
# 평균적혈구용적(Mean Cell Volume) 완료. 현재 완료한 객체:  116
# 적혈구용적률(Hematocrit) 완료. 현재 완료한 객체:  117
# 혈색소(Hemoglobin) 완료. 현재 완료한 객체:  118
# 절대호중구수(Absolute neutrophil count) 완료. 현재 완료한 객체:  119
# 적혈구 침강속도(Erythrocyte sedimentation rate) 완료. 현재 완료한 객체:  120
# 프로트롬빈 시간(Prothrombin time) 완료. 현재 완료한 객체:  121
# 디다이머(D-dimer) 완료. 현재 완료한 객체:  122
# 활성화부분트롬보플라스틴시간(activated partial thromboplastin time) 완료. 현재 완료한 객체:  123
# 빈혈 검사(Anemia Test) 완료. 현재 완료한 객체:  124
# 전혈구검사(Complete blood cell count) 완료. 현재 완료한 객체:  125
# 유리 싸이록신(Free thyroxine) 완료. 현재 완료한 객체:  126
# 난포자극호르몬(Follicle stimulating hormone) 완료. 현재 완료한 객체:  127
# 황체형성호르몬(Luteinizing hormone) 완료. 현재 완료한 객체:  128
# 테스토스테론(Testosterone) 완료. 현재 완료한 객체:  129
# 싸이로글로불린(Thyroglobulin) 완료. 현재 완료한 객체:  130
# 갑상선자극호르몬(Thyroid stimulating hormone) 완료. 현재 완료한 객체:  131
# 알파태아단백(Alpha(α) Feto-Protein ) 완료. 현재 완료한 객체:  132
# 암항원 15-3 (Cancer Antigen 15-3) 완료. 현재 완료한 객체:  133
# 암항원 19-9(Cancer Antigen 19-9) 완료. 현재 완료한 객체:  134
# 암배아항원(Carcino-Embryonic Antigen) 완료. 현재 완료한 객체:  135
# 전립선특이항원(Prostate-Specific Antigen) 완료. 현재 완료한 객체:  136
# 임신성 당뇨(Gestational diabetes) 완료. 현재 완료한 객체:  137
# 에스트라디올(Estradiol) 완료. 현재 완료한 객체:  138
# 항뮬러관호르몬(Anti-Mullerian Hormone) 완료. 현재 완료한 객체:  139
# 당뇨 검사(Diabetes mellitus Tset) 완료. 현재 완료한 객체:  140
# 혈압 검사(Blood pressure) 완료. 현재 완료한 객체:  141
# 체질량지수(Body Mass Index) 완료. 현재 완료한 객체:  142
# 내장지방(Visceral fat) 완료. 현재 완료한 객체:  143
# 뼈스캔(Bone scan ) 완료. 현재 완료한 객체:  144
# 쉴링검사(Schilling test) 완료. 현재 완료한 객체:  145
# 심근관류스캔(Myocardial perfusion scan) 완료. 현재 완료한 객체:  146
# 방사성 요오드 전신스캔(I-131 Whole body scan) 완료. 현재 완료한 객체:  147
# 폐관류스캔(Lung Perfusion scan) 완료. 현재 완료한 객체:  148
# 초음파 땀샘 흡입술(Ultrasonic surgical aspiration for axillary osmidr) 완료. 현재 완료한 객체:  149
# 유리 지방 이식 수술(Free fat grafting) 완료. 현재 완료한 객체:  150
# 유두 재건술(Nipple reconstruction) 완료. 현재 완료한 객체:  151
# 안면 거상 수술(Face lift surgery) 완료. 현재 완료한 객체:  152
# 안검하수 교정 수술(Correction of Blepharoptosis ) 완료. 현재 완료한 객체:  153
# 안검성형술(Blepharoplasty) 완료. 현재 완료한 객체:  154
# 쌍꺼풀 수술(Double-eyelid surgery) 완료. 현재 완료한 객체:  155
# 복부성형술(Abdominoplasty) 완료. 현재 완료한 객체:  156
# 구순성형술(Labioplasty) 완료. 현재 완료한 객체:  157
# 구개성형술(Palatoplasty) 완료. 현재 완료한 객체:  158
# 사시 교정 수술(Strabismus surgery) 완료. 현재 완료한 객체:  159
# 백내장 제거 및 인공 수정체 삽입 수술(Cataract surgery) 완료. 현재 완료한 객체:  160
# 라식을 이용한 근시 교정 수술(Laser in situ keratomileusis) 완료. 현재 완료한 객체:  161
# 누낭비강연결술(Dacryocystorhinostomy) 완료. 현재 완료한 객체:  162
# 척수자극기 삽입술(Spinal cord stimulator insertion) 완료. 현재 완료한 객체:  163
# 척수강내 약물 주입 펌프 이식술(Intrathecal drug pump insertion) 완료. 현재 완료한 객체:  164
# 수핵성형술(Nucleoplasty) 완료. 현재 완료한 객체:  165
# 치핵절제술(Hemorrhoidectomy) 완료. 현재 완료한 객체:  166
# 충수절제술(Appendectomy) 완료. 현재 완료한 객체:  167
# 장루복원술(Stoma take-down) 완료. 현재 완료한 객체:  168
# 요 시험지 검사(Urine dipstick testing) 완료. 현재 완료한 객체:  169
# 광역동 치료술(Photodynamic therapy) 완료. 현재 완료한 객체:  170
# 경구 포도당 부하 검사(Oral glucose tolerance test) 완료. 현재 완료한 객체:  171
# 고주파 열 응고술(Radiofrequency ablation) 완료. 현재 완료한 객체:  172
# 전신 조사(Total body irradiation) 완료. 현재 완료한 객체:  173
# 색전술(Embolization) 완료. 현재 완료한 객체:  174
# 펀치 생검(Punch biopsy) 완료. 현재 완료한 객체:  175
# 감시 림프절 생검(Sentinel lymph node biopsy) 완료. 현재 완료한 객체:  176
# 개방 생검(Open biopsy) 완료. 현재 완료한 객체:  177
# 중심정맥관 삽입술(Central venous catheter insertion) 완료. 현재 완료한 객체:  178
# 광선요법(Phototherapy) 완료. 현재 완료한 객체:  179
# 복수 천자(Paracentesis) 완료. 현재 완료한 객체:  180
# 유두 유륜 문신 시술(Nipple tattoo) 완료. 현재 완료한 객체:  181
# 수혈(Tranfusion) 완료. 현재 완료한 객체:  182
# 추간판 조영술(Spinal discography) 완료. 현재 완료한 객체:  183
# 증식 치료술(Prolotherapy) 완료. 현재 완료한 객체:  184
# 경막외강 유착 박리술 및 신경성형술(Epidural adhesiolysis or decompressive neuroplasty) 완료. 현재 완료한 객체:  185
# 무릎신경 차단술(Nerve block in knee joint) 완료. 현재 완료한 객체:  186
# 말초신경 차단(Peripheral nerve block) 완료. 현재 완료한 객체:  187
# 경막외 마취(Epidural anesthesia) 완료. 현재 완료한 객체:  188
# 경막외 자가 혈액 봉합술(Epidural blood patch) 완료. 현재 완료한 객체:  189
# 늑간신경차단(Intercostal nerve block) 완료. 현재 완료한 객체:  190
# 맥박 산소 측정법(Pulse oximetry) 완료. 현재 완료한 객체:  191
# 세침흡인검사(Fine neddle aspiration biopsy) 완료. 현재 완료한 객체:  192
# 내시경적 회전근개 봉합 수술ㆍ견봉 성형 수술(Arthroscopic rotator cuff repairㆍAcromioplasty) 완료. 현재 완료한 객체:  193
# 경추 전방 디스크 제거 수술ㆍ유합 수술(Anterior cervical discectomy and interbody fusion) 완료. 현재 완료한 객체:  194
# 경추 인공 디스크 치환 수술(Cervical total disc replacement) 완료. 현재 완료한 객체:  195
# 건박리술(Tenolysis) 완료. 현재 완료한 객체:  196
# 건근성형술(Tenomyoplasty) 완료. 현재 완료한 객체:  197
# 후방 감압 수술ㆍ후외측, 후방 요추체 유합 수술 (DecompressionㆍPosterolateral) 완료. 현재 완료한 객체:  198
# 소아 뇌성 마비 교정 수술(Surgical treatment in cerebral palsy) 완료. 현재 완료한 객체:  199
# 골이식(Bone graft) 완료. 현재 완료한 객체:  200
# 개방정복술(Open reduction) 완료. 현재 완료한 객체:  201
# 복식자궁절제술(Total abdominal hysterectomy ) 완료. 현재 완료한 객체:  202
# 복강경 자궁절제술(Laparoscopic hysterectomy) 완료. 현재 완료한 객체:  203
# 근치자궁절제술(Radical hysterectomy) 완료. 현재 완료한 객체:  204
# 소음순절제술(Nymphectomy) 완료. 현재 완료한 객체:  205
# 골반내용물적출술(Pelvic exenteration ) 완료. 현재 완료한 객체:  206
# 여성 요실금 수술(Female sling operation) 완료. 현재 완료한 객체:  207
# 굴절교정레이저각막절제술(PRK, LASIK, LASEK) 완료. 현재 완료한 객체:  208
# 공막돌륭술(Scleral buckling) 완료. 현재 완료한 객체:  209
# 공막노출법(Bare sclera) 완료. 현재 완료한 객체:  210
# 각막절개술(Keratotomy) 완료. 현재 완료한 객체:  211
# 척추성형술(Vertebroplasty) 완료. 현재 완료한 객체:  212
# 생식세포자궁관내이식(Gamete intrafallopian transfer ) 완료. 현재 완료한 객체:  213
# 보조생식기술(Assisted reproductive technology ) 완료. 현재 완료한 객체:  214
# 갑상선(경부) 중심바늘 생검 검사(Thyroid(Cervical) core needle biopsy) 완료. 현재 완료한 객체:  215
# 갑상선(경부) 미세침 흡인 생검 검사(Thyroid(Cervical) fine needle aspiration biopsy ) 완료. 현재 완료한 객체:  216
# 갑상선 고주파 열치료 시술(Thyroid radiofrequency ablation) 완료. 현재 완료한 객체:  217
# 갑상선 경피적 에탄올 주입 시술(Thyroid percutaneous ethanol injection) 완료. 현재 완료한 객체:  218
# 간동맥 화학 색전술(Transcatheter arterial chemoembolization) 완료. 현재 완료한 객체:  219
# 여성호르몬부하검사(Estrogen challenge test) 완료. 현재 완료한 객체:  220
# 비수축검사(Nonstress test) 완료. 현재 완료한 객체:  221
# 검안경검사(Ophthalmoscopy ) 완료. 현재 완료한 객체:  222
# 낭위연결술(Cystogastrostomy ) 완료. 현재 완료한 객체:  223
# 낭공장연결술(Cystojejunostomy) 완료. 현재 완료한 객체:  224
# 낭십이지장연결술(Cystoduodenostomy) 완료. 현재 완료한 객체:  225
# 낭장연결술(Cystoenterostomy ) 완료. 현재 완료한 객체:  226
# 부분층 피부 이식(Split-skin graft) 완료. 현재 완료한 객체:  227
# 유방재건술(Breast reconstruction) 완료. 현재 완료한 객체:  228
# 유방줄임술(Breast reduction) 완료. 현재 완료한 객체:  229
# 유방확대술(Breast augmentation) 완료. 현재 완료한 객체:  230
# 지방흡인술(Suction lipectomy) 완료. 현재 완료한 객체:  231
# 코성형술(Rhinoplasty ) 완료. 현재 완료한 객체:  232
# 코높임술(Augmentation rhinoplasty ) 완료. 현재 완료한 객체:  233
# 코축소술(Reduction rhinoplasty ) 완료. 현재 완료한 객체:  234
# 턱뼈각축소술(mandibular angle reduction) 완료. 현재 완료한 객체:  235
# 하악골절제술(Mandibular osteotomy) 완료. 현재 완료한 객체:  236
# 고실성형술(Tympanoplasty ) 완료. 현재 완료한 객체:  237
# 고막절개술(Myringotomy) 완료. 현재 완료한 객체:  238
# 비장절제술(Splenectomy ) 완료. 현재 완료한 객체:  239
# 결장 부분 절제술(Partial Colectomy) 완료. 현재 완료한 객체:  240
# 결장절제술(Colectomy ) 완료. 현재 완료한 객체:  241
# 복회음절제술(Abdominoperineal resection) 완료. 현재 완료한 객체:  242
# 결장창냄술(Colostomy) 완료. 현재 완료한 객체:  243
# 공장창냄술(Jejunostomy ) 완료. 현재 완료한 객체:  244
# 경접형동 접근법에 의한 뇌하수체 종양 제거술(Transsphenoid approach to pituitary adenoma ) 완료. 현재 완료한 객체:  245
# 뇌동맥류 결찰술(Cerebral aneurysm clipping) 완료. 현재 완료한 객체:  246
# 뇌실 복강 간 단락술(Ventriculoperitoneal shunt) 완료. 현재 완료한 객체:  247
# 뇌실창냄술(Ventriculostomy) 완료. 현재 완료한 객체:  248
# 개두술(Craniotomy) 완료. 현재 완료한 객체:  249
# 구개수구개인두성형술(Uvulopalatopharyngoplasty ) 완료. 현재 완료한 객체:  250
# 목젖절제술(Uvulectomy ) 완료. 현재 완료한 객체:  251
# 상악 절제 수술(Maxillectomy) 완료. 현재 완료한 객체:  252
# 경비 위내시경 검사(Transnasal Esophagogastroduodenoscopy) 완료. 현재 완료한 객체:  253
# 내시경 점막하절제술(Endoscopic submucosal dissection) 완료. 현재 완료한 객체:  254
# 내시경 초음파 검사(Endoscopic ultrasound scopy) 완료. 현재 완료한 객체:  255
# 대장내시경 풍선확장술(Colonoscopic balloon dilation) 완료. 현재 완료한 객체:  256
# 밀러 애보트 튜브 삽입술(Miller?Abbott tube intubation) 완료. 현재 완료한 객체:  257
# 식도 기능 검사(Esophageal function tests) 완료. 현재 완료한 객체:  258
# 24시간 산 역류 검사(24hr Esophageal pH monitoring tests ) 완료. 현재 완료한 객체:  259
# 기관지 폐용적 축소술(Bronchoscopic lung volume reduction) 완료. 현재 완료한 객체:  260
# 기관경검사(Tracheoscopy ) 완료. 현재 완료한 객체:  261
# 기관내삽관(Endotracheal intubation) 완료. 현재 완료한 객체:  262
# 기관지 유발 검사(Bronchial Provocation Test) 완료. 현재 완료한 객체:  263
# 기관지 동맥 색전술(Bronchial artery embolization ) 완료. 현재 완료한 객체:  264
# 기관지 내시경 검사(Bronchoscopy ) 완료. 현재 완료한 객체:  265
# 비경검사법(Rhinoscopy) 완료. 현재 완료한 객체:  266
# 골접합술(Osteosynthesis) 완료. 현재 완료한 객체:  267
# 대퇴골 회전 절골술(Femoral osteotomy) 완료. 현재 완료한 객체:  268
# 관절성형술(Arthroplasty ) 완료. 현재 완료한 객체:  269
# 무지외반증 교정 수술(Hallux valgus osteotomy) 완료. 현재 완료한 객체:  270
# 근막절개술(Fasciotomy ) 완료. 현재 완료한 객체:  271
# 관절유합술(Arthrodesis ) 완료. 현재 완료한 객체:  272
# 자궁경부 원추절제술(Conization ) 완료. 현재 완료한 객체:  273
# 자궁근종절제술(Hysteromyomectomy) 완료. 현재 완료한 객체:  274
# 자궁내막절제 (Endometrial ablation ) 완료. 현재 완료한 객체:  275
# 아메드 밸브 삽입 수술(Ahmed valve implantation ) 완료. 현재 완료한 객체:  276
# 섬유주 절제 수술(Trabeculectomy) 완료. 현재 완료한 객체:  277
# 융모막융모생검(Chorionic villus sampling ) 완료. 현재 완료한 객체:  278
# 유도분만(labor induction) 완료. 현재 완료한 객체:  279
# 뇌초음파검사(Echoencephalography ) 완료. 현재 완료한 객체:  280
# 경두개도플러(Transcranial doppler ) 완료. 현재 완료한 객체:  281
# 목동맥조영술(Carotid angiography ) 완료. 현재 완료한 객체:  282
# 대동맥조영술(Aortography ) 완료. 현재 완료한 객체:  283
# 관절천자(Arthresis) 완료. 현재 완료한 객체:  284
# 삼차신경로 절단술(Trigeminal tractotomy) 완료. 현재 완료한 객체:  285
# 자궁내막생검(Endometrial biopsy ) 완료. 현재 완료한 객체:  286
# 자궁경검사법(Hysteroscopy) 완료. 현재 완료한 객체:  287
# 자궁경관내소파술(Endocervical curettage ) 완료. 현재 완료한 객체:  288
# 시야측정법(Perimetry) 완료. 현재 완료한 객체:  289
# 레이저 홍채절개술(Laser iridotomy ) 완료. 현재 완료한 객체:  290
# 광역학 레이저 치료(Photodynamic Therapy) 완료. 현재 완료한 객체:  291
# 경피적 승모판 풍선확장술(Percutaneous balloon mitral valvuloplasty) 완료. 현재 완료한 객체:  292
# 신경절제술(Neurectomy) 완료. 현재 완료한 객체:  293
# 신경절개술(Neurotomy) 완료. 현재 완료한 객체:  294
# 신경뿌리절제술(Rhizotomy) 완료. 현재 완료한 객체:  295
# 신경봉합술(Neurorrhaphy) 완료. 현재 완료한 객체:  296
# 신상파괴술(Thalamotomy) 완료. 현재 완료한 객체:  297
# 설소대 절제 수술(Frenotomy) 완료. 현재 완료한 객체:  298
# 유양돌기절제술(Mastoidectomy) 완료. 현재 완료한 객체:  299
# 전이개 누공 절제 수술(Preauricular fistulectomy) 완료. 현재 완료한 객체:  300
# 전정신경절단술(Vestibular neurectomy) 완료. 현재 완료한 객체:  301
# 폐기능검사(Pulmonary function test) 완료. 현재 완료한 객체:  302
# 투베르쿨린(Tuberculin test ) 완료. 현재 완료한 객체:  303
# 산소요법(Oxygen therapy ) 완료. 현재 완료한 객체:  304
# 비침습양압환기(Noninvasive positive-pressure ventilation) 완료. 현재 완료한 객체:  305
# 동맥혈가스분석(Arterial blood gas study) 완료. 현재 완료한 객체:  306
# 동맥천자(Arteriopuncture) 완료. 현재 완료한 객체:  307
# 정맥류 폐색술(Variceal sclerotherapy) 완료. 현재 완료한 객체:  308
# 정맥류 결찰술(Variceal ligation) 완료. 현재 완료한 객체:  309
# 목정맥경유간속문맥전신순환지름술(Transjugular intrahepatic portosystemic shunt ) 완료. 현재 완료한 객체:  310
# 경피적 에탄올 주입술(Percutaneous ethanol injection) 완료. 현재 완료한 객체:  311
# 조직형검사(Tissue typing ) 완료. 현재 완료한 객체:  312
# 응집검사(Agglutination test) 완료. 현재 완료한 객체:  313
# 매독 검사(Syphilis tests) 완료. 현재 완료한 객체:  314
# 신경전도검사(Electroneurography) 완료. 현재 완료한 객체:  315
# 위석 제거술(Removal of gastric bezoar) 완료. 현재 완료한 객체:  316
# 위세척(Gastric lavage) 완료. 현재 완료한 객체:  317
# 대장폴립절제술(Colonic polypectomy) 완료. 현재 완료한 객체:  318
# 피부간경유쓸개관배액술(Percutaneous transhepatic biliary drainage) 완료. 현재 완료한 객체:  319
# 이경검사(Otoscopy) 완료. 현재 완료한 객체:  320
# 전정기능검사(Vestibular function test ) 완료. 현재 완료한 객체:  321
# 아르곤 플라즈마 소작술(Argon plasma coagulation) 완료. 현재 완료한 객체:  322
# 식도 점막하 박리술(Esophageal submucosal dissection) 완료. 현재 완료한 객체:  323
# 식도, 위 스텐트 삽입술(Esophageal & Gastric strent insertion) 완료. 현재 완료한 객체:  324
# 위내시경 풍선 확장술 [아칼라지아](Esophageal balloon dilatation) 완료. 현재 완료한 객체:  325
# 위내시경 풍선 확장술 [TTS](Endoscopic balloon dilatation) 완료. 현재 완료한 객체:  326
# 요소호기검사(Urea breath test) 완료. 현재 완료한 객체:  327
# 문맥대정맥지름술(Portocaval shunt operation) 완료. 현재 완료한 객체:  328
# 자궁부속기절제술(Adnexectomy) 완료. 현재 완료한 객체:  329
# 자궁사이막절제술(Uterine septectomy) 완료. 현재 완료한 객체:  330
# 자궁성형술(Uteroplasty) 완료. 현재 완료한 객체:  331
# 자궁목절제술(Cervicectomy) 완료. 현재 완료한 객체:  332
# 엑시머 레이저를 이용한 근시 교정 수술(Photorefractive keratectomy) 완료. 현재 완료한 객체:  333
# 인공 슬관절 치환 수술(Total knee replacement arthroplasty) 완료. 현재 완료한 객체:  334
# 인공 고관절 치환 수술(Total hip arthroplasty ) 완료. 현재 완료한 객체:  335
# 인공 견관절 치환 수술(Total shoulder replacement ) 완료. 현재 완료한 객체:  336
# 연골판 절제 수술(Arthroscopic meniscectomy) 완료. 현재 완료한 객체:  337
# 연골판 이식 수술(Cartilaginous plate transplantation ) 완료. 현재 완료한 객체:  338
# 연골판 봉합 수술(Cartilaginous plate repair) 완료. 현재 완료한 객체:  339
# 수근관 이완 수술(Carpal tunnel release ) 완료. 현재 완료한 객체:  340
# 비구 주위 절골 수술(Periacetabular osteotomy ) 완료. 현재 완료한 객체:  341
# 반관절성형술(Hemiarthroplasty) 완료. 현재 완료한 객체:  342
# 안와감압술(Orbital decompression) 완료. 현재 완료한 객체:  343
# 입체 정위 진공 보조 유방 생검술(Stereotactic vacuum assistant breast biopsy) 완료. 현재 완료한 객체:  344
# 진공 보조 유방 생검술 검사(Vacuum assistant [Vacora] breast biopsy) 완료. 현재 완료한 객체:  345
# 문맥조영술(Portography ) 완료. 현재 완료한 객체:  346
# 피부접촉검사(Patch test ) 완료. 현재 완료한 객체:  347
# 질경검사법(Vaginoscopy) 완료. 현재 완료한 객체:  348
# 질경유초음파촬영술(Transvaginal ultrasonography ) 완료. 현재 완료한 객체:  349
# 야그 레이저 수정체낭 절개술(YAG laser capsulotomy) 완료. 현재 완료한 객체:  350
# 유리체강 내 약물 주입술(Intravitreal injection ) 완료. 현재 완료한 객체:  351
# 안압측정법(Tonometry) 완료. 현재 완료한 객체:  352
# 쉴링검사(Schilling test) 완료. 현재 완료한 객체:  353
# 사람유두종바이러스검사(Human papilloma virus test) 완료. 현재 완료한 객체:  354
# 복부 대동맥류 인조 혈관 치환 수술(Graft replacement of abdominal aortic aneurysm) 완료. 현재 완료한 객체:  355
# 경동맥내막절제술(Carotid endarterectomy) 완료. 현재 완료한 객체:  356
# 치아절제술을 동반한 발치(Extraction with odontectomy ) 완료. 현재 완료한 객체:  357
# 양악수술(2-jaw surgery) 완료. 현재 완료한 객체:  358
# 치아성형술(Odontoplasty ) 완료. 현재 완료한 객체:  359
# 치아교정술(Orthodontics) 완료. 현재 완료한 객체:  360
# 치수절단술(Pulpotomy) 완료. 현재 완료한 객체:  361
# 구강전정성형술(Vestibuloplasty ) 완료. 현재 완료한 객체:  362
# 임플란트 수술(Implant surgery) 완료. 현재 완료한 객체:  363
# 췌장절제술(Pancreatectomy) 완료. 현재 완료한 객체:  364
# 췌위연결술(Pancreaticogastrostomy) 완료. 현재 완료한 객체:  365
# 이자샘창자절제술(Pancreatoduodenectomy) 완료. 현재 완료한 객체:  366
# 췌공장연결술(Pancreaticojejunostomy) 완료. 현재 완료한 객체:  367
# 나비뼈경유수술(Transsphenoidal surgery ) 완료. 현재 완료한 객체:  368
# 교감신경절제술(Sympathectomy ) 완료. 현재 완료한 객체:  369
# 간이식수술(Liver transplantation) 완료. 현재 완료한 객체:  370
# 비중격 교정술(Nasal septoplasty) 완료. 현재 완료한 객체:  371
# 하비갑개 성형술(Turbinoplasty) 완료. 현재 완료한 객체:  372
# 후두 미세 현미경 수술(Laryngeal microsurgery) 완료. 현재 완료한 객체:  373
# 전체대장절제술(Total proctocolectomy ) 완료. 현재 완료한 객체:  374
# 직장절제술(Proctectomy ) 완료. 현재 완료한 객체:  375
# 항문괄약근절개술(Anal sphincterotomy ) 완료. 현재 완료한 객체:  376
# 대망절제술(Omentectomy) 완료. 현재 완료한 객체:  377
# 하지정맥류 경화요법(Sclerotherapy for varicose vein) 완료. 현재 완료한 객체:  378
# 흉막유착술(Pleurodesis) 완료. 현재 완료한 객체:  379
# 폐활량측정법(Spirometry ) 완료. 현재 완료한 객체:  380
# 메타콜린유발검사(Metacholine challenge test ) 완료. 현재 완료한 객체:  381
# 스케일링(Scaling) 완료. 현재 완료한 객체:  382
# 뇌심부 자극수술(Deep brain stimulation) 완료. 현재 완료한 객체:  383
# 허리교감신경절제술(Lumbar sympathectomy) 완료. 현재 완료한 객체:  384
# 내시경하 비인두 검사(Endoscopic nasopharynx examination ) 완료. 현재 완료한 객체:  385
# 구불결장내시경검사(Sigmoidoscopy) 완료. 현재 완료한 객체:  386
# 캡슐내시경 검사(Capsule endoscopy ) 완료. 현재 완료한 객체:  387
# 위전도검사(Electrogastrography) 완료. 현재 완료한 객체:  388
# 직장항문기능검사(Anorectal functional test) 완료. 현재 완료한 객체:  389
# 하지정맥류 결찰 및 발거술(High ligation and stripping of varicose vein) 완료. 현재 완료한 객체:  390
# 동정맥루 수술(Arteriovenous fistula operation) 완료. 현재 완료한 객체:  391
# 이종이식(Heteroplastic transplantation ) 완료. 현재 완료한 객체:  392
# 갑상선절제술(Thyroidectomy) 완료. 현재 완료한 객체:  393
# 질고정술(Vaginopexy) 완료. 현재 완료한 객체:  394
# 질성형술(Vaginoplasty ) 완료. 현재 완료한 객체:  395
# 회전근개 봉합 수술ㆍ견봉 성형 수술(Rotator Cuff repairㆍacromioplasty) 완료. 현재 완료한 객체:  396
# 현미경하 미세 추간판 절제 수술(Open lumbar microdiscectomy) 완료. 현재 완료한 객체:  397
# 추간판절제술(Discectomy ) 완료. 현재 완료한 객체:  398
# 척추후궁절제술(Laminectomy ) 완료. 현재 완료한 객체:  399
# 척추측만증 변형 교정 수술ㆍ후방 고정 수술(Scoliosis correction surgeryㆍposterior fusion) 완료. 현재 완료한 객체:  400
# 발목 관절 유합 수술(Ankle fusion) 완료. 현재 완료한 객체:  401
# 인공 발목 관절 치환술(Total ankle replacement arthroplasty) 완료. 현재 완료한 객체:  402
# 절골술(Osteotomy) 완료. 현재 완료한 객체:  403
# 무릎절골술(Knee osteotomy ) 완료. 현재 완료한 객체:  404
# 편도절제술(Tonsillectomy ) 완료. 현재 완료한 객체:  405
# 타액선조영술(Sialography) 완료. 현재 완료한 객체:  406
# 경피적 신루설치술(Percutaneous nephrostomy ) 완료. 현재 완료한 객체:  407
# 자궁목질세포검사(Papanicolaou test) 완료. 현재 완료한 객체:  408
# 황체기 자궁내막생검(Luteal phase endometrial biopsy ) 완료. 현재 완료한 객체:  409
# 질확대경생검(Colposcopy directed biopsy ) 완료. 현재 완료한 객체:  410
# 파노라마 안저검사(Panoramic view ) 완료. 현재 완료한 객체:  411
# 안저검사(Fundus examination) 완료. 현재 완료한 객체:  412
# 혈관성형술 및 스텐트 삽입술(Angioplastyㆍstent insertion) 완료. 현재 완료한 객체:  413
# 형광안저혈관조영술(Fluorescein angiography) 완료. 현재 완료한 객체:  414
# 빛간섭단층촬영(Optical coherence tomography) 완료. 현재 완료한 객체:  415
# 망막전위도검사(Electroretinography ) 완료. 현재 완료한 객체:  416
# WADA 검사(Wada test) 완료. 현재 완료한 객체:  417
# 기립경사검사(Tilt test ) 완료. 현재 완료한 객체:  418
# 도플러초음파(Doppler ultrasound ) 완료. 현재 완료한 객체:  419
# 보툴리눔 독소 주사 치료(Botulinum toxin injection) 완료. 현재 완료한 객체:  420
# 척추천자(Spinal tap ) 완료. 현재 완료한 객체:  421
# 혈관 재개통 요법(Thrombolytic therapy ) 완료. 현재 완료한 객체:  422
# 폐 관류 스캔(Pulmonary perfusion scan ) 완료. 현재 완료한 객체:  423
# 심근 관류 스캔(Myocardial perfusion scan ) 완료. 현재 완료한 객체:  424
# 뼈 스캔(Bone scan ) 완료. 현재 완료한 객체:  425
# 유발검사(Provocation test ) 완료. 현재 완료한 객체:  426
# 아프가점수(Apgar score) 완료. 현재 완료한 객체:  427
# 포경수술(Circumcision) 완료. 현재 완료한 객체:  428
# 음경 보형물 삽입 수술(Penile prosthesis implantation) 완료. 현재 완료한 객체:  429
# 정계정맥류 결찰술(Varicocele ligation) 완료. 현재 완료한 객체:  430
# 정관 복원술(Vasovasostomy) 완료. 현재 완료한 객체:  431
# 고환고정술(Orchiopexy) 완료. 현재 완료한 객체:  432
# 고환절제술(Orchiectomy) 완료. 현재 완료한 객체:  433
# 남성 요실금 수술(Male sling operation) 완료. 현재 완료한 객체:  434
# 방광대치술(Bladder substitution) 완료. 현재 완료한 객체:  435
# 방광결석제거술(Cystolithotomy) 완료. 현재 완료한 객체:  436
# 방광창냄술(Cystostomy) 완료. 현재 완료한 객체:  437
# 방광확대술(Bladder augmentation) 완료. 현재 완료한 객체:  438
# 부신절제술(Suprarenalectomy) 완료. 현재 완료한 객체:  439
# 신우성형술(Pyeloplasty) 완료. 현재 완료한 객체:  440
# 신장절개결석제거술(Nephrolithotomy) 완료. 현재 완료한 객체:  441
# 신장절제술(Nephrectomy) 완료. 현재 완료한 객체:  442
# 요관절제술(Ureterectomy) 완료. 현재 완료한 객체:  443
# 요도경유절제술(Transurethral resection) 완료. 현재 완료한 객체:  444
# 요도고정술(Urethropexy) 완료. 현재 완료한 객체:  445
# 요도절개술(Urethrotomy) 완료. 현재 완료한 객체:  446
# 전립선절제술(Prostatectomy) 완료. 현재 완료한 객체:  447
# 정관절제술(Vasectomy) 완료. 현재 완료한 객체:  448
# 난관결찰술(Tubal ligation) 완료. 현재 완료한 객체:  449
# 난관절제술(Tubectomy) 완료. 현재 완료한 객체:  450
# 자궁경부원형묶음술(Cervical cerclage) 완료. 현재 완료한 객체:  451
# 제왕절개술(Cesarean section) 완료. 현재 완료한 객체:  452
# 식도근육절개술(Esophagomyotomy) 완료. 현재 완료한 객체:  453
# 대부분위절제술(Subtotal gastrectomy ) 완료. 현재 완료한 객체:  454
# 미주신경절단술(Vagotomy) 완료. 현재 완료한 객체:  455
# 부분위절제술(Partial gastrectomy ) 완료. 현재 완료한 객체:  456
# 위공장연결술(Gastrojejunostomy) 완료. 현재 완료한 객체:  457
# 유문성형술(Pyloroplasty) 완료. 현재 완료한 객체:  458
# 유문절개술(Pylorotomy) 완료. 현재 완료한 객체:  459
# 전체위절제술(Total gastrectomy ) 완료. 현재 완료한 객체:  460
# 광범위국소절제술(Wide local excision) 완료. 현재 완료한 객체:  461
# 구역절제술(Segmentectomy ) 완료. 현재 완료한 객체:  462
# 림프절절제술(Lymphadenectomy ) 완료. 현재 완료한 객체:  463
# 복강정맥지름술(Peritoneovenous shunt) 완료. 현재 완료한 객체:  464
# 샛길절제술(Fistulectomy ) 완료. 현재 완료한 객체:  465
# 우회로조성술(Bypass surgery) 완료. 현재 완료한 객체:  466
# 신장이식술(Renal transplantation ) 완료. 현재 완료한 객체:  467
# 종괴절제술(Lumpectomy ) 완료. 현재 완료한 객체:  468
# 종양절제술(Tumorectomy ) 완료. 현재 완료한 객체:  469
# 죽은조직제거술(Debridement ) 완료. 현재 완료한 객체:  470
# 지방절제술(Lipectomy ) 완료. 현재 완료한 객체:  471
# 신장고정술(Nephropexy) 완료. 현재 완료한 객체:  472
# 탈장 교정 수술(Herniorrhaphy) 완료. 현재 완료한 객체:  473
# 최소침습수술(Minimally invasive surgery) 완료. 현재 완료한 객체:  474
# 가슴관삽입(술)(Thoracostomy) 완료. 현재 완료한 객체:  475
# 가슴샘절제술(Thymectomy ) 완료. 현재 완료한 객체:  476
# 개심술(Open heart surgery) 완료. 현재 완료한 객체:  477
# 개흉술(Thoracotomy) 완료. 현재 완료한 객체:  478
# 기관성형술(Tracheoplasty) 완료. 현재 완료한 객체:  479
# 기관절개술(Tracheostomy) 완료. 현재 완료한 객체:  480
# 기관지성형술(Bronchoplasty) 완료. 현재 완료한 객체:  481
# 대동맥양측대퇴동맥우회술(Aortobifemoral bypass ) 완료. 현재 완료한 객체:  482
# 승모판절개술(Mitral valvulotomy) 완료. 현재 완료한 객체:  483
# 복장뼈절개술(Sternotomy) 완료. 현재 완료한 객체:  484
# 식도암 절제수술(Resection of esophageal cancer) 완료. 현재 완료한 객체:  485
# 심실 보조 장치(Ventricular assist device) 완료. 현재 완료한 객체:  486
# 심장동맥우회로조성술(Coronary artery bypass surgery) 완료. 현재 완료한 객체:  487
# 쐐기절제술(Wedge resection) 완료. 현재 완료한 객체:  488
# 심방중격천공술(Atrial septostomy) 완료. 현재 완료한 객체:  489
# 인공판막대치술(prosthetic valve replacement) 완료. 현재 완료한 객체:  490
# 오목가슴 교정 수술(Funnel chest) 완료. 현재 완료한 객체:  491
# 판막성형술(Valvuloplasty) 완료. 현재 완료한 객체:  492
# 판막절개술(Valvulotomy) 완료. 현재 완료한 객체:  493
# 폐절제술(Pneumonectomy) 완료. 현재 완료한 객체:  494
# 체외충격파쇄석술(Extracorporeal shock wave lithotripsy) 완료. 현재 완료한 객체:  495
# 발기유발검사(Artificial erection test) 완료. 현재 완료한 객체:  496
# 방광경검사(Cystoscopy) 완료. 현재 완료한 객체:  497
# 방광내압측정술(Cystometry) 완료. 현재 완료한 객체:  498
# 요도경검사(Urethroscopy) 완료. 현재 완료한 객체:  499
# 요역동학검사 (Urodynamic study) 완료. 현재 완료한 객체:  500
# 요흐름검사(Uroflowmetry) 완료. 현재 완료한 객체:  501
# 음경진동각검사(Penile biothesiometry) 완료. 현재 완료한 객체:  502
# 역행성 요도조영술(Retrograde urethrography) 완료. 현재 완료한 객체:  503
# 체외수정 (In vitro fertilization ) 완료. 현재 완료한 객체:  504
# 태아경(Fetoscopy) 완료. 현재 완료한 객체:  505
# 탯줄천자(Cordocentesis) 완료. 현재 완료한 객체:  506
# 피부 수분 손실량 측정 검사(Transepidermal water loss) 완료. 현재 완료한 객체:  507
# 복막투석(Peritoneal dialysis) 완료. 현재 완료한 객체:  508
# 신장기능검사(Renal function test) 완료. 현재 완료한 객체:  509
# 혈액투석(Hemodialysis) 완료. 현재 완료한 객체:  510
# 식도경유심장초음파검사(Transesophageal echocardiography ) 완료. 현재 완료한 객체:  511
# 심장율동전환(Cardioversion) 완료. 현재 완료한 객체:  512
# 심장초음파검사(Echocardiography) 완료. 현재 완료한 객체:  513
# 약물 부하 심장 초음파 검사(Stress echocardiography) 완료. 현재 완료한 객체:  514
# 운동 부하 심장 초음파 검사(Exercise Stress Echocardiogram) 완료. 현재 완료한 객체:  515
# 폐모세혈관쐐기압(Pulmonary artery occlusion pressure) 완료. 현재 완료한 객체:  516
# 운동 부하 심전도 검사(Exercise stress electrocardiography) 완료. 현재 완료한 객체:  517
# 약물유발검사(Drug provocation test) 완료. 현재 완료한 객체:  518
# 인공 심박동기/제세동기 삽입 및 교환술(Pacemaker or ICD insertion and changing) 완료. 현재 완료한 객체:  519
# 제세동(Defibrillation) 완료. 현재 완료한 객체:  520
# 방사선 촬영(X-ray) 완료. 현재 완료한 객체:  521
# 종양 고주파 절제술(Radiofrequency ablation for tumors) 완료. 현재 완료한 객체:  522
# 콩팥요관방광단순촬영(Kidneys, ureter, and bladder X-ray) 완료. 현재 완료한 객체:  523
# 안진검사(Nystagmography) 완료. 현재 완료한 객체:  524
# 로르샤흐검사 (Rorschach test) 완료. 현재 완료한 객체:  525
# 베일리 영유아 발달검사(Bayley scales of infant development) 완료. 현재 완료한 객체:  526
# 지능검사(Intelligence test ) 완료. 현재 완료한 객체:  527
# 치료약물농도감시(Therapeutic drug monitoring) 완료. 현재 완료한 객체:  528
# 쿰즈검사(Coombs' test) 완료. 현재 완료한 객체:  529
# 크실로오스검사(D-xylose test ) 완료. 현재 완료한 객체:  530
# 햄검사(Ham's test ) 완료. 현재 완료한 객체:  531
# 치료적 채혈술(Phlebotomy) 완료. 현재 완료한 객체:  532
# 냉동요법(Cryotherapy ) 완료. 현재 완료한 객체:  533
# 레이저 시술(Laser treatment) 완료. 현재 완료한 객체:  534
# 보톡스 시술(Botulinum toxin therapy ) 완료. 현재 완료한 객체:  535
# 필러 시술(Filler injection) 완료. 현재 완료한 객체:  536
# 혈액희석법(Hemodilution ) 완료. 현재 완료한 객체:  537
# 혈장교환술(Plasma exchange ) 완료. 현재 완료한 객체:  538
# 혈장분리교환술(Plasmapheresis ) 완료. 현재 완료한 객체:  539
# 대동맥 내 풍선펌프(Intra-aortic balloon pump) 완료. 현재 완료한 객체:  540
# 심장막천자(Pericardiocentesis) 완료. 현재 완료한 객체:  541
# 체외막산소화(Extracorporeal membrane oxygenation) 완료. 현재 완료한 객체:  542
# 폐천자(Pneumocentesis) 완료. 현재 완료한 객체:  543

# %%
# http://www.amc.seoul.kr/asan/healthinfo/management/managementDetail.do?managementId=
# 확인용 테스트   검사/시술/수술 정보 0-542  -> 총 543개
i = 482
print("검사명: ", interventions[i].name)
print("관련 신체 부위: ")
for part in interventions[i].related_parts:
    print(part)
print("관련 질환 분야: ")
for area in interventions[i].related_areas:
    print(area)
print("관련 검사: ")
for intervention in interventions[i].related_interventions:
    print(intervention)
print("관련 진료과: ")
for medDep in interventions[i].medDeps:
    print(medDep)
print()
print("관련 설명: ")
for k, v in interventions[i].descrips.items():
    print(k)
    print(v)
print()
print("관련 질환 분야: ")
for dis in interventions[i].related_diseases:
    print(dis)
print("관련 인체 부위: ")
for body in interventions[i].related_bodies:
    print(body)

# %%
txt= ""
for intervention in interventions:
    txt = txt + "================================= \n"
    txt = txt + "검사명: " + intervention.name + "\n"
    if len(intervention.related_parts) >= 1:
        txt = txt + "관련 신체 부위: " + "\n"
        for part in intervention.related_parts:
            txt = txt + part + "\n"
    if len(intervention.related_areas) >= 1:
        txt = txt + "관련 질환 분야: " + "\n"
        for area in intervention.related_areas:
            txt = txt + area + "\n"
    if len(intervention.related_interventions) >= 1:
        txt = txt + "관련 검사: " + "\n"
        for intervene in intervention.related_interventions:
            txt = txt + intervene + "\n"
    if len(intervention.medDeps) >= 1:
        txt = txt + "관련 진료과: " + "\n"
        for medDep in intervention.medDeps:
            txt = txt + medDep + "\n"
    if len(intervention.descrips) >= 1:
        txt = txt + "검사 설명: " + "\n"
        for k, v in intervention.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    if len(intervention.related_diseases) >= 1:
        txt = txt + "관련 질환: " + "\n"
        for disease in intervention.related_diseases:
            txt = txt + disease + "\n"
    if len(intervention.related_bodies) >= 1:
        txt = txt + "관련 인체: " + "\n"
        for body in intervention.related_bodies:
            txt = txt + body + "\n"
    txt = txt + "================================= \n"

with open("./output/whole/interventions.txt", "w") as text_file:
    text_file.write(txt)

# %%
txt= ""
for intervention in interventions:
    txt = txt + "검사명: " + intervention.name + "\n"
    if len(intervention.descrips) >= 1:
        txt = txt + "검사 설명: " + "\n"
        for k, v in intervention.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"

with open("./output/whole/interventions_description.txt", "w") as text_file:
    text_file.write(txt)

# %%
for intervention in interventions:
    if (intervention.name.find('/') != -1):
        print(intervention.name)
        intervention.name = intervention.name.replace('/','')

# %%
for intervention in interventions:
    txt= ""
    txt = txt + "검사명: " + intervention.name + "\n"
    if len(intervention.descrips) >= 1:
        txt = txt + "검사 설명: " + "\n"
        for k, v in intervention.descrips.items():
            txt = txt + k + "\n"
            txt = txt + v + "\n"
    with open("./output/interventions_"+ intervention.name +".txt", "w") as text_file:
        text_file.write(txt)

# %% [markdown]
# # 통합 txt 파일 생성

# %%
bodies_txt = open("./output/whole/bodies.txt", "r")
diseases_txt = open("./output/whole/diseases.txt", "r")
interventions_txt = open("./output/whole/interventions.txt", "r")

with open("./output/whole/whole.txt", "w") as t:
    t.write(bodies_txt.read())
    t.write(diseases_txt.read())
    t.write(interventions_txt.read())

# %%
bodies_description_txt = open("./output/whole/bodies_description.txt", "r")
diseases_description_txt = open("./output/whole/diseases_description.txt", "r")
interventions_description_txt = open("./output/whole/interventions_description.txt", "r")

with open("./output/whole/whole_description.txt", "w") as t:
    bodies_string = bodies_description_txt.read()
    diseases_string = diseases_description_txt.read()
    interventions_string = interventions_description_txt.read()
    whole = bodies_string + "\n" + diseases_string + "\n" + interventions_string
    t.write(whole)

# %% [markdown]
# # Renaming
#
# ETRI CLI는 파일명의 공백을 허용하지 않으므로 파일명의 공백을 모두 없애는 작업

# %%
files = os.listdir("./output/")
new_files=[]
for file in files:
    new_files.append(file.replace(" ", "_"))

for old, new in zip(files, new_files):
    os.rename("./output/"+old, "./output/"+new)

# %% [markdown]
# # Exporting Python objects as XML

# %%
#import xml.etree.ElementTree as ET
from lxml import etree as ET
from lxml.builder import E

# %%
bodies_xml = E("bodies")
for body in bodies:
    body_name = E("body_name", body.name)
    body_part = E("body_part", body.part)
    body_disease = E("body_disease", body.disease)
    body_medDep = E("body_medDep", body.medDep)
    
    body_related_diseases = E("body_related_diseases")
    for related_disease in body.related_diseases:
        body_related_diseases.append(E("body_related_disease", related_disease))
        
    body_related_interventions = E("body_related_interventions")
    for related_intervention in body.related_interventions:
        body_related_interventions.append(E("body_related_intervention", related_intervention))
        
    body_description = E("body_description")
    for k, v in body.descrips.items():
        if k == "정의":
            body_description.append(E("body_definition", v))
        if k == "위치":
            body_description.append(E("location", v))
        if k == "구조":
            body_description.append(E("architecture", v))
        if k == "기능":
            body_description.append(E("function", v))
        if k == "헬스팁":
            body_description.append(E("body_tip", v))
    
    body = E("body", body_name, body_part, body_disease, body_medDep, body_related_diseases, body_related_interventions, body_description)
    bodies_xml.append(body)

declaration = """<?xml version="1.0" encoding="utf-8" standalone="yes"?>
<!DOCTYPE bodies [
<!ELEMENT bodies (body)*>
<!ELEMENT body (body_name, body_part, body_disease, body_medDep, body_related_diseases, body_related_interventions, body_description)*>
<!ELEMENT body_name (#PCDATA)>
<!ELEMENT body_part (#PCDATA)>
<!ELEMENT body_disease (#PCDATA)>
<!ELEMENT body_medDep (#PCDATA)>
<!ELEMENT body_related_diseases (body_related_disease)*>
<!ELEMENT body_related_disease (#PCDATA)>
<!ELEMENT body_related_interventions (body_related_intervention)*>
<!ELEMENT body_related_intervention (#PCDATA)>
<!ELEMENT body_description (body_definition?, location?, architecture?, function?, body_tip?)*>
<!ELEMENT body_definition (#PCDATA)>
<!ELEMENT location (#PCDATA)>
<!ELEMENT architecture (#PCDATA)>
<!ELEMENT function (#PCDATA)>
<!ELEMENT body_tip (#PCDATA)>
]>
<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->
"""

dec_byte = str.encode(declaration)
bodies_tree = ET.ElementTree(bodies_xml)
end_com= str.encode("<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->")

with open("./xml/bodies.xml", "wb") as f:
    f.write(dec_byte)
    f.write(ET.tostring(bodies_tree, xml_declaration=False, encoding="utf-8", pretty_print=True))
    f.write(end_com)

# %%
diseases_xml = E("diseases")
for disease in diseases:
    disease_name = E("disease_name", disease.name)
    synonym = E("synonym", disease.synonym)
    
    disease_related_diseases = E("disease_related_diseases")
    for related_disease in disease.related_diseases:
        disease_related_diseases.append(E("disease_related_disease", related_disease))
        
    related_symptoms = E("related_symptoms")
    for related_symptom in disease.related_symptoms:
        related_symptoms.append(E("related_symptom", related_symptom))
        
    disease_medDeps = E("disease_medDeps")
    for medDep in disease.medDeps:
        disease_medDeps.append(E("disease_medDep", medDep))
        
    disease_description = E("disease_description")
    for k, v in disease.descrips.items():
        if k == "정의":
            disease_description.append(E("disease_definition", v))
        if k == "원인":
            disease_description.append(E("cause", v))
        if k == "증상":
            disease_description.append(E("symptom", v))
        if k == "진단":
            disease_description.append(E("diagnosis", v))
        if k == "경과":
            disease_description.append(E("progress", v))
        if k == "주의사항":
            disease_description.append(E("disease_caution", v))
    
    disease = E("disease", disease_name, disease_related_diseases, related_symptoms, disease_medDeps, synonym, disease_description)
    diseases_xml.append(disease)

declaration = """<?xml version="1.0" encoding="utf-8" standalone="yes"?>
<!DOCTYPE diseases [
<!ELEMENT diseases (disease)*>
<!ELEMENT disease (disease_name?, disease_related_diseases?, related_symptoms?, disease_medDeps?, synonym?, disease_description?)*>
<!ELEMENT disease_name (#PCDATA)>
<!ELEMENT synonym (#PCDATA)>
<!ELEMENT disease_related_diseases (disease_related_disease)*>
<!ELEMENT disease_related_disease (#PCDATA)>
<!ELEMENT related_symptoms (related_symptom)*>
<!ELEMENT related_symptom (#PCDATA)>
<!ELEMENT disease_medDeps (disease_medDep)*>
<!ELEMENT disease_medDep (#PCDATA)>
<!ELEMENT disease_description (disease_definition?, cause?, symptom?, diagnosis?, progress?, disease_caution?)*>
<!ELEMENT disease_definition (#PCDATA)>
<!ELEMENT cause (#PCDATA)>
<!ELEMENT symptom (#PCDATA)>
<!ELEMENT diagnosis (#PCDATA)>
<!ELEMENT progress (#PCDATA)>
<!ELEMENT disease_caution (#PCDATA)>
]>
<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->
"""
dec_byte = str.encode(declaration)
end_com= str.encode("<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->")
diseases_tree = ET.ElementTree(diseases_xml)
with open("./xml/diseases.xml", "wb") as f:
    f.write(dec_byte)
    f.write(ET.tostring(diseases_tree, xml_declaration=False, encoding="utf-8", pretty_print=True))
    f.write(end_com)

# %%
interventions_xml = E("interventions")
for intervention in interventions:
    intervention_name = E("intervention_name", intervention.name)
    
    intervention_related_diseases = E("intervention_related_diseases")
    for related_disease in intervention.related_diseases:
        intervention_related_diseases.append(E("intervention_related_disease", related_disease))
        
    related_bodies = E("related_bodies")
    for related_body in intervention.related_bodies:
        related_bodies.append(E("related_body", related_body))
        
    related_parts = E("related_parts")
    for related_part in intervention.related_parts:
        related_parts.append(E("related_part", related_part))
        
    related_areas = E("related_areas")
    for related_area in intervention.related_areas:
        related_areas.append(E("related_area", related_area))
        
    related_interventions = E("related_interventions")
    for related_intervention in intervention.related_interventions:
        related_interventions.append(E("related_intervention", related_intervention))
        
    intervention_medDeps = E("intervention_medDeps")
    for medDep in intervention.medDeps:
        intervention_medDeps.append(E("intervention_medDep", medDep))
        
    intervention_description = E("intervention_description")
    for k, v in intervention.descrips.items():
        if k == "정의":
            intervention_description.append(E("intervention_definition", v))
        if k == "적응증":
            intervention_description.append(E("indication", v))
        if k == "준비사항":
            intervention_description.append(E("preparation", v))
        if k == "검사시기":
            intervention_description.append(E("stage", v))
        if k == "검사/시술/수술 방법":
            intervention_description.append(E("method", v))
        if k == "검사결과":
            intervention_description.append(E("result", v))
        if k == "주의사항":
            intervention_description.append(E("intervention_caution", v))
        if k == "헬스팁":
            intervention_description.append(E("intervention_tip", v))
    
    intervention = E("intervention", intervention_name, related_parts, related_areas, related_interventions, intervention_related_diseases, related_bodies, intervention_medDeps, intervention_description)  
    interventions_xml.append(intervention)

declaration = """<?xml version="1.0" encoding="utf-8" standalone="yes"?>
<!DOCTYPE interventions [
<!ELEMENT interventions (intervention)*>
<!ELEMENT intervention (intervention_name?, related_parts?, related_areas?, related_interventions?, intervention_related_diseases?, related_bodies?, intervention_medDeps?, intervention_description?)*>
<!ELEMENT intervention_name (#PCDATA)>
<!ELEMENT intervention_related_diseases (intervention_related_disease)*>
<!ELEMENT intervention_related_disease (#PCDATA)>
<!ELEMENT related_bodies (related_body)*>
<!ELEMENT related_body (#PCDATA)>
<!ELEMENT related_parts (related_part)*>
<!ELEMENT related_part (#PCDATA)>
<!ELEMENT related_areas (related_area)*>
<!ELEMENT related_area (#PCDATA)>
<!ELEMENT related_interventions (related_intervention)*>
<!ELEMENT related_intervention (#PCDATA)>
<!ELEMENT intervention_medDeps (intervention_medDep)*>
<!ELEMENT intervention_medDep (#PCDATA)>
<!ELEMENT intervention_description (intervention_definition?, indication?, preparation?, stage?, method?, result?, intervention_caution?, intervention_tip?)*>
<!ELEMENT intervention_definition (#PCDATA)>
<!ELEMENT indication (#PCDATA)>
<!ELEMENT preparation (#PCDATA)>
<!ELEMENT stage (#PCDATA)>
<!ELEMENT method (#PCDATA)>
<!ELEMENT result (#PCDATA)>
<!ELEMENT intervention_caution (#PCDATA)>
<!ELEMENT intervention_tip (#PCDATA)>
]>
<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->
"""

dec_byte = str.encode(declaration)
end_com= str.encode("<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->")
interventions_tree = ET.ElementTree(interventions_xml)
with open("./xml/interventions.xml", "wb") as f:
    f.write(dec_byte)
    f.write(ET.tostring(interventions_tree, xml_declaration=False, encoding="utf-8", pretty_print=True))
    f.write(end_com)

# %%
declaration = """<?xml version="1.0" encoding="utf-8" standalone="yes"?>
<!DOCTYPE seoulAsan [

<!ELEMENT seoulAsan (bodies+, diseases+, interventions+)*>

<!ELEMENT bodies (body)*>
<!ELEMENT body (body_name, body_part, body_disease, body_medDep, body_related_diseases, body_related_interventions, body_description)*>
<!ELEMENT body_name (#PCDATA)>
<!ELEMENT body_part (#PCDATA)>
<!ELEMENT body_disease (#PCDATA)>
<!ELEMENT body_medDep (#PCDATA)>
<!ELEMENT body_related_diseases (body_related_disease)*>
<!ELEMENT body_related_disease (#PCDATA)>
<!ELEMENT body_related_interventions (body_related_intervention)*>
<!ELEMENT body_related_intervention (#PCDATA)>
<!ELEMENT body_description (body_definition?, location?, architecture?, function?, body_tip?)*>
<!ELEMENT body_definition (#PCDATA)>
<!ELEMENT location (#PCDATA)>
<!ELEMENT architecture (#PCDATA)>
<!ELEMENT function (#PCDATA)>
<!ELEMENT body_tip (#PCDATA)>

<!ELEMENT diseases (disease)*>
<!ELEMENT disease (disease_name?, disease_related_diseases?, related_symptoms?, disease_medDeps?, synonym?, disease_description?)*>
<!ELEMENT disease_name (#PCDATA)>
<!ELEMENT synonym (#PCDATA)>
<!ELEMENT disease_related_diseases (disease_related_disease)*>
<!ELEMENT disease_related_disease (#PCDATA)>
<!ELEMENT related_symptoms (related_symptom)*>
<!ELEMENT related_symptom (#PCDATA)>
<!ELEMENT disease_medDeps (disease_medDep)*>
<!ELEMENT disease_medDep (#PCDATA)>
<!ELEMENT disease_description (disease_definition?, cause?, symptom?, diagnosis?, progress?, disease_caution?)*>
<!ELEMENT disease_definition (#PCDATA)>
<!ELEMENT cause (#PCDATA)>
<!ELEMENT symptom (#PCDATA)>
<!ELEMENT diagnosis (#PCDATA)>
<!ELEMENT progress (#PCDATA)>
<!ELEMENT disease_caution (#PCDATA)>

<!ELEMENT interventions (intervention)*>
<!ELEMENT intervention (intervention_name?, related_parts?, related_areas?, related_interventions?, intervention_related_diseases?, related_bodies?, intervention_medDeps?, intervention_description?)*>
<!ELEMENT intervention_name (#PCDATA)>
<!ELEMENT intervention_related_diseases (intervention_related_disease)*>
<!ELEMENT intervention_related_disease (#PCDATA)>
<!ELEMENT related_bodies (related_body)*>
<!ELEMENT related_body (#PCDATA)>
<!ELEMENT related_parts (related_part)*>
<!ELEMENT related_part (#PCDATA)>
<!ELEMENT related_areas (related_area)*>
<!ELEMENT related_area (#PCDATA)>
<!ELEMENT related_interventions (related_intervention)*>
<!ELEMENT related_intervention (#PCDATA)>
<!ELEMENT intervention_medDeps (intervention_medDep)*>
<!ELEMENT intervention_medDep (#PCDATA)>
<!ELEMENT intervention_description (intervention_definition?, indication?, preparation?, stage?, method?, result?, intervention_caution?, intervention_tip?)*>
<!ELEMENT intervention_definition (#PCDATA)>
<!ELEMENT indication (#PCDATA)>
<!ELEMENT preparation (#PCDATA)>
<!ELEMENT stage (#PCDATA)>
<!ELEMENT method (#PCDATA)>
<!ELEMENT result (#PCDATA)>
<!ELEMENT intervention_caution (#PCDATA)>
<!ELEMENT intervention_tip (#PCDATA)>
]>
<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->
"""
whole_xml = E("seoulAsan", bodies_xml, diseases_xml, interventions_xml)
whole_tree = ET.ElementTree(whole_xml)
dec_byte = str.encode(declaration)
end_com = str.encode("<!--Seongtae Kim 2020-06-06 https://github.com/Seongtae-Kim -->")

with open("./xml/SeoulAsanData.xml", "wb") as f:
    f.write(dec_byte)
    f.write(ET.tostring(whole_tree, xml_declaration=False, encoding="utf-8", pretty_print=True))
    f.write(end_com)
